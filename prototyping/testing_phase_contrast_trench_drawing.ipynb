# %%
import sys
sys.path.insert(0,'/home/georgeos/Documents/GitHub/SYMPTOMM2')
import matplotlib.pyplot as plt
import numpy as np
from SYMPTOMM import cell_geometry
from SYMPTOMM.cell import Cell
from SYMPTOMM.scene_functions import create_space, step_and_update
from SYMPTOMM.plotting import matplot_scene
from SYMPTOMM.trench_geometry import trench_creator
import pyglet
import pymunk
from pymunk.pyglet_util import DrawOptions
import pickle
from copy import deepcopy
window = pyglet.window.Window(700, 1100, "MM Trench test", resizable=False)
options = DrawOptions()
import pandas as pd
space = create_space()
space.gravity = 0, -0.3
dt = 1/100


pix_mic_conv = 10
scale_factor = 3 * pix_mic_conv

trench_length = 25*scale_factor

trench_creator(1.5*scale_factor,trench_length,(35,0),space) # Coordinates of bottom left corner of the trench
#trench_creator(35,trench_length,(35*3,0),space) # Coordinates of bottom left corner of the trench
#trench_creator(35,trench_length,(35*5,0),space) # Coordinates of bottom left corner of the trench

cell1 = Cell(
    length = 3.5*scale_factor,  
    width = 1*scale_factor, 
    resolution = 60, 
    position = (20+35,40), 
    angle = 0.8, 
    space = space,
    dt = 1/60,
    growth_rate_constant = 1,
    max_length = 3.5*scale_factor,
    max_length_mean =3.5*scale_factor,
    max_length_var = 0.1*np.sqrt(scale_factor),
    width_var = 0.03*np.sqrt(scale_factor),
    width_mean = 1*scale_factor
)


cells = [cell1]

# %%
scale_factor
# Out:
# 30

# %%
#body = pymunk.Body(1,1666,pymunk.Body.KINEMATIC)
#body.position = 120,100
#poly = pymunk.Poly.create_box(body,size=(40,40))
#space.add(body,poly)

@window.event
def on_draw():
    window.clear()
    space.debug_draw(options)

      

pyglet_draw = True
matplot_draw = False

phys_iters = 200

if pyglet_draw == True:
    if __name__ == "__main__":
        pyglet.clock.schedule_interval(step_and_update, dt, cells, space, phys_iters,ylim=trench_length)
        pyglet.app.run()
elif matplot_draw:
    for x in range(200):
        step_and_update(dt=dt, cells=cells, space=space, phys_iters=phys_iters,ylim=trench_length)
        matplot_scene(x,cells, "/home/georgeos/Documents/GitHub/SYMPTOMM2/figures")
else:
    cell_timeseries = []
    for x in range(650):
        cells = step_and_update(dt=dt, cells=cells, space=space, phys_iters=phys_iters,ylim=trench_length)
        if x > 250:
            cell_timeseries.append(deepcopy(cells))
    with open("output_pickles/cell_timeseries_medium.p", "wb") as f:
        pickle.dump(cell_timeseries, f)
    with open("output_pickles/space_medium.p", "wb") as f:
        pickle.dump(space, f)
# Out:
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 2 cells
# 3 cells
# 3 cells
# 3 cells
# 3 cells
# 3 cells
# 3 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 4 cells
# 5 cells
# 5 cells
# 5 cells
# 5 cells
# 5 cells
# 5 cells
# 6 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 9 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 7 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 9 cells
# 9 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 7 cells
# 7 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 7 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 9 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 8 cells
# 7 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 9 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 9 cells
# 9 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 8 cells
# 7 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 10 cells
# 9 cells
# 9 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 9 cells
# 8 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 10 cells
# 9 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 9 cells
# 8 cells
# 8 cells
# 9 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 7 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 10 cells
# 9 cells
# 9 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 8 cells
# 7 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 9 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 8 cells
# 7 cells
# 7 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 9 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 7 cells
# 8 cells
# 8 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 10 cells
# 9 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 10 cells
# 9 cells
# 9 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 9 cells
# 9 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 8 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 9 cells
# 8 cells
# 8 cells
# 9 cells
# 9 cells
# 10 cells
# 9 cells
# 9 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 10 cells
# 9 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 7 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 9 cells
# 9 cells
# 11 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 9 cells
# 9 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 9 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 9 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 9 cells
# 9 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 8 cells
# 9 cells
# 8 cells
# 8 cells
# 9 cells
# 9 cells
# 10 cells
# 9 cells
# 9 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# From cffi callback <function SpaceDebugDrawOptions.__init__.<locals>.f4 at 0x7f35713c1700>:
# Traceback (most recent call last):
#   File "/home/georgeos/anaconda3/envs/SYMPTOMM2/lib/python3.9/site-packages/pyglet/graphics/vertexdomain.py", line 241, in _safe_alloc
#     return self.allocator.alloc(count)
#   File "/home/georgeos/anaconda3/envs/SYMPTOMM2/lib/python3.9/site-packages/pyglet/graphics/allocation.py", line 194, in alloc
#     raise AllocatorMemoryException(self.capacity + size - free_size)
# pyglet.graphics.allocation.AllocatorMemoryException: 269
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/georgeos/anaconda3/envs/SYMPTOMM2/lib/python3.9/site-packages/pymunk/space_debug_draw_options.py", line 124, in f4
#     self.draw_polygon(vs, radius, self._c(outline_color), self._c(fill_color))
#   File "/home/georgeos/anaconda3/envs/SYMPTOMM2/lib/python3.9/site-packages/pymunk/pyglet_util.py", line 228, in draw_polygon
#     self.batch.add(l, mode, None, ("v2f", vs), ("c4B", fill_color.as_int() * l))
#   File "/home/georgeos/anaconda3/envs/SYMPTOMM2/lib/python3.9/site-packages/pyglet/graphics/__init__.py", line 369, in add
#     vlist = domain.create(count)
#   File "/home/georgeos/anaconda3/envs/SYMPTOMM2/lib/python3.9/site-packages/pyglet/graphics/vertexdomain.py", line 271, in create
#     start = self._safe_alloc(count)
#   File "/home/georgeos/anaconda3/envs/SYMPTOMM2/lib/python3.9/site-packages/pyglet/graphics/vertexdomain.py", line 246, in _safe_alloc
#     buffer.resize(capacity * buffer.element_size)
#   File "/home/georgeos/anaconda3/envs/SYMPTOMM2/lib/python3.9/site-packages/pyglet/graphics/vertexbuffer.py", line 433, in resize
#     glPushClientAttrib(GL_CLIENT_VERTEX_ARRAY_BIT)
#   File "/home/georgeos/anaconda3/envs/SYMPTOMM2/lib/python3.9/site-packages/pyglet/gl/lib.py", line 104, in errcheck
#     error = gl.glGetError()
# KeyboardInterrupt
# 8 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 7 cells
# 8 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 10 cells
# 9 cells
# 10 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 11 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 10 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 9 cells
# 8 cells
# 8 cells
# 8 cells
# 8 cells
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-91801e0b6474> in <module>
#      19     if __name__ == "__main__":
#      20         pyglet.clock.schedule_interval(step_and_update, dt, cells, space, phys_iters,ylim=trench_length)
# ---> 21         pyglet.app.run()
#      22 elif matplot_draw:
#      23     for x in range(200):
#
# ~/anaconda3/envs/SYMPTOMM2/lib/python3.9/site-packages/pyglet/app/__init__.py in run()
#     105
#     106     """
# --> 107     event_loop.run()
#     108
#     109
#
# ~/anaconda3/envs/SYMPTOMM2/lib/python3.9/site-packages/pyglet/app/base.py in run(self)
#     165
#     166         while not self.has_exit:
# --> 167             timeout = self.idle()
#     168             platform_event_loop.step(timeout)
#     169
#
# ~/anaconda3/envs/SYMPTOMM2/lib/python3.9/site-packages/pyglet/app/base.py in idle(self)
#     235         """
#     236         dt = self.clock.update_time()
# --> 237         redraw_all = self.clock.call_scheduled_functions(dt)
#     238
#     239         # Redraw all windows
#
# ~/anaconda3/envs/SYMPTOMM2/lib/python3.9/site-packages/pyglet/clock.py in call_scheduled_functions(self, dt)
#     290
#     291             # execute the callback
# --> 292             item.func(now - item.last_ts, *item.args, **item.kwargs)
#     293
#     294             if item.interval:
#
# ~/Documents/GitHub/SYMPTOMM2/SYMPTOMM/scene_functions.py in step_and_update(dt, cells, space, phys_iters, ylim)
#      60
#      61     for _ in range(phys_iters):
# ---> 62         space.step(dt)
#      63     update_cell_positions(cells)
#      64
#
# ~/anaconda3/envs/SYMPTOMM2/lib/python3.9/site-packages/pymunk/space.py in step(self, dt)
#     580                 cp.cpHastySpaceStep(self._space, dt)
#     581             else:
# --> 582                 cp.cpSpaceStep(self._space, dt)
#     583             self._removed_shapes = {}
#     584         finally:
#
# KeyboardInterrupt:

# %%
def get_trench_segments(space):
    trench_shapes = []
    for shape, body in zip(space.shapes, space.bodies):
        if body.body_type == 2:
            trench_shapes.append(shape)
    return trench_shapes

# %%
for x in get_trench_segments(space):
    print(x.bb)
# Out:
# BB(left=34.0, bottom=-1.0, right=36.0, top=41.0)
# BB(left=34.0, bottom=-1.0, right=37.0, top=40.0)
# BB(left=34.0, bottom=-1.0, right=38.0, top=39.0)
# BB(left=34.0, bottom=-1.0, right=39.0, top=38.0)
# BB(left=34.0, bottom=-1.0, right=40.0, top=37.0)
# BB(left=34.0, bottom=-1.0, right=41.0, top=36.0)
# BB(left=34.0, bottom=-1.0, right=42.0, top=35.0)
# BB(left=34.0, bottom=-1.0, right=43.0, top=34.0)
# BB(left=34.0, bottom=-1.0, right=44.0, top=33.0)
# BB(left=34.0, bottom=-1.0, right=45.0, top=32.0)
# BB(left=34.0, bottom=-1.0, right=46.0, top=31.0)
# BB(left=34.0, bottom=-1.0, right=47.0, top=30.0)
# BB(left=34.0, bottom=-1.0, right=48.0, top=29.0)
# BB(left=34.0, bottom=-1.0, right=49.0, top=28.0)
# BB(left=34.0, bottom=-1.0, right=50.0, top=27.0)
# BB(left=34.0, bottom=-1.0, right=51.0, top=26.0)
# BB(left=34.0, bottom=-1.0, right=52.0, top=25.0)
# BB(left=34.0, bottom=-1.0, right=53.0, top=24.0)
# BB(left=34.0, bottom=-1.0, right=54.0, top=23.0)
# BB(left=34.0, bottom=-1.0, right=55.0, top=22.0)
# BB(left=34.0, bottom=-1.0, right=56.0, top=21.0)
# BB(left=34.0, bottom=-1.0, right=57.0, top=20.0)
# BB(left=34.0, bottom=-1.0, right=58.0, top=19.0)
# BB(left=34.0, bottom=-1.0, right=59.0, top=18.0)
# BB(left=34.0, bottom=-1.0, right=60.0, top=17.0)
# BB(left=34.0, bottom=-1.0, right=61.0, top=16.0)
# BB(left=34.0, bottom=-1.0, right=62.0, top=15.0)
# BB(left=34.0, bottom=-1.0, right=63.0, top=14.0)
# BB(left=34.0, bottom=-1.0, right=64.0, top=13.0)
# BB(left=34.0, bottom=-1.0, right=65.0, top=12.0)
# BB(left=34.0, bottom=-1.0, right=66.0, top=11.0)
# BB(left=34.0, bottom=-1.0, right=67.0, top=10.0)
# BB(left=34.0, bottom=-1.0, right=68.0, top=9.0)
# BB(left=34.0, bottom=-1.0, right=69.0, top=8.0)
# BB(left=34.0, bottom=-1.0, right=70.0, top=7.0)
# BB(left=34.0, bottom=-1.0, right=71.0, top=6.0)
# BB(left=34.0, bottom=-1.0, right=72.0, top=5.0)
# BB(left=34.0, bottom=-1.0, right=73.0, top=4.0)
# BB(left=34.0, bottom=-1.0, right=74.0, top=3.0)
# BB(left=34.0, bottom=-1.0, right=75.0, top=2.0)
# BB(left=94.0, bottom=-1.0, right=96.0, top=41.0)
# BB(left=93.0, bottom=-1.0, right=96.0, top=40.0)
# BB(left=92.0, bottom=-1.0, right=96.0, top=39.0)
# BB(left=91.0, bottom=-1.0, right=96.0, top=38.0)
# BB(left=90.0, bottom=-1.0, right=96.0, top=37.0)
# BB(left=89.0, bottom=-1.0, right=96.0, top=36.0)
# BB(left=88.0, bottom=-1.0, right=96.0, top=35.0)
# BB(left=87.0, bottom=-1.0, right=96.0, top=34.0)
# BB(left=86.0, bottom=-1.0, right=96.0, top=33.0)
# BB(left=85.0, bottom=-1.0, right=96.0, top=32.0)
# BB(left=84.0, bottom=-1.0, right=96.0, top=31.0)
# BB(left=83.0, bottom=-1.0, right=96.0, top=30.0)
# BB(left=82.0, bottom=-1.0, right=96.0, top=29.0)
# BB(left=81.0, bottom=-1.0, right=96.0, top=28.0)
# BB(left=80.0, bottom=-1.0, right=96.0, top=27.0)
# BB(left=79.0, bottom=-1.0, right=96.0, top=26.0)
# BB(left=78.0, bottom=-1.0, right=96.0, top=25.0)
# BB(left=77.0, bottom=-1.0, right=96.0, top=24.0)
# BB(left=76.0, bottom=-1.0, right=96.0, top=23.0)
# BB(left=75.0, bottom=-1.0, right=96.0, top=22.0)
# BB(left=74.0, bottom=-1.0, right=96.0, top=21.0)
# BB(left=73.0, bottom=-1.0, right=96.0, top=20.0)
# BB(left=72.0, bottom=-1.0, right=96.0, top=19.0)
# BB(left=71.0, bottom=-1.0, right=96.0, top=18.0)
# BB(left=70.0, bottom=-1.0, right=96.0, top=17.0)
# BB(left=69.0, bottom=-1.0, right=96.0, top=16.0)
# BB(left=68.0, bottom=-1.0, right=96.0, top=15.0)
# BB(left=67.0, bottom=-1.0, right=96.0, top=14.0)
# BB(left=66.0, bottom=-1.0, right=96.0, top=13.0)
# BB(left=65.0, bottom=-1.0, right=96.0, top=12.0)
# BB(left=64.0, bottom=-1.0, right=96.0, top=11.0)
# BB(left=63.0, bottom=-1.0, right=96.0, top=10.0)
# BB(left=62.0, bottom=-1.0, right=96.0, top=9.0)
# BB(left=61.0, bottom=-1.0, right=96.0, top=8.0)
# BB(left=60.0, bottom=-1.0, right=96.0, top=7.0)
# BB(left=59.0, bottom=-1.0, right=96.0, top=6.0)
# BB(left=58.0, bottom=-1.0, right=96.0, top=5.0)
# BB(left=57.0, bottom=-1.0, right=96.0, top=4.0)
# BB(left=56.0, bottom=-1.0, right=96.0, top=3.0)
# BB(left=55.0, bottom=-1.0, right=96.0, top=2.0)
# BB(left=34.0, bottom=-1.0, right=36.0, top=751.0)
# BB(left=94.0, bottom=-1.0, right=96.0, top=751.0)
# BB(left=15.0, bottom=-10.0, right=35.0, top=760.0)
# BB(left=95.0, bottom=-10.0, right=115.0, top=760.0)
