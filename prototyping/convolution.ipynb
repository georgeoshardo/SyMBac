# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import rotate
import pickle
import sys
sys.path.insert(0,'/home/georgeos/Documents/GitHub/SYMPTOMM2')
import itertools
from joblib import Parallel, delayed
from skimage.morphology import opening
from PIL import Image       
import pymunk
from skimage.transform import PiecewiseAffineTransform, warp
from skimage import data
from copy import deepcopy
from SYMPTOMM.PSF import get_fluorescence_kernel
import cupy as cp
from cupyx.scipy.ndimage import convolve as cuconvolve
from skimage.exposure import rescale_intensity
from scipy.ndimage import convolve
from skimage.transform import rescale, resize, downscale_local_mean
from scipy.special import jv, jve
from matplotlib_scalebar.scalebar import ScaleBar
from skimage.exposure import match_histograms
from numpy import fft
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from SYMPTOMM.image_manipulation.pySHINE import sfMatch, pol2cart, cart2pol, lumMatch
import tifffile
from skimage.util import random_noise
import skimage
from skimage.morphology import opening
import os
viridis = cm.get_cmap('viridis', 12)
newcolors = viridis(np.linspace(0, 1, 256))

YFP_cols = np.zeros((256,4))
for x in range(256):
    YFP_cols[x,0:2]=x/256
YFP_cols[:,-1]=1

CFP_cols = np.zeros((256,4))
for x in range(256):
    CFP_cols[x,1:3]=x/256
CFP_cols[:,-1]=1

RFP_cols = np.zeros((256,4))
for x in range(256):
    RFP_cols[x,0]=x/256
RFP_cols[:,-1]=1

GFP_cols = np.zeros((256,4))
for x in range(256):
    GFP_cols[x,1]=x/256
GFP_cols[:,-1]=1

BFP_cols = np.zeros((256,4))
for x in range(256):
    BFP_cols[x,2]=x/256
BFP_cols[:,-1]=1

YFP_cmap = ListedColormap(YFP_cols)
CFP_cmap = ListedColormap(CFP_cols)
RFP_cmap = ListedColormap(RFP_cols)
GFP_cmap = ListedColormap(GFP_cols)
BFP_cmap = ListedColormap(BFP_cols)
fluorescent_cmaps = [YFP_cmap,CFP_cmap,RFP_cmap,GFP_cmap,BFP_cmap]
em_wavelengths = [0.527,0.480,0.610,0.507,0.44]
RGBs = [[0,1],[1,2],[0],[1],[2]]
names = ["YFP","CFP","RFP","GFP","BFP"]

# %%
# Function to add camera noise
def add_camera_noise(input_irrad_photons, qe=0.69, sensitivity=5.88,
                     dark_noise=2.29, bitdepth=12, baseline=100,
                     rs=np.random.RandomState(seed=42)):
 
    # Add shot noise
    photons = rs.poisson(input_irrad_photons, size=input_irrad_photons.shape)
    
    # Convert to electrons
    electrons = qe * photons
    
    # Add dark noise
    electrons_out = rs.normal(scale=dark_noise, size=electrons.shape) + electrons
    
    # Convert to ADU and add baseline
    max_adu     = np.int(2**bitdepth - 1)
    adu         = (electrons_out * sensitivity).astype(np.int) # Convert to discrete numbers
    adu += baseline
    adu[adu > max_adu] = max_adu # models pixel saturation
    
    return adu

def get_fluorescence_kernel(Lambda,NA,n,radius,scale):
    r = np.arange(-radius,radius+1)
    kaw = 2* NA/n * np.pi/Lambda
    xx,yy = np.meshgrid(r,r)
    xx, yy = xx*scale, yy*scale
    rr = np.sqrt(xx**2+yy**2) * kaw 
    PSF = (2*jv(1,rr)/(rr))**2
    PSF[radius,radius] = 1
    return PSF, np.sqrt(xx**2+yy**2)

radius = 50
scale=0.11/5
Lambda = 0.63
NA = 0.95
PSF = get_fluorescence_kernel(Lambda,NA,1,radius,scale)
plt.imshow(np.sqrt(PSF[0]))
scalebar = ScaleBar(scale, 'um')
plt.axis("off")
plt.gca().add_artist(scalebar)
plt.show()
plt.imshow(PSF[1])
# Out:
# <ipython-input-2-943804d1f9d9>:29: RuntimeWarning: invalid value encountered in true_divide
#   PSF = (2*jv(1,rr)/(rr))**2

# %%
plt.plot(PSF[1][int(radius),:],PSF[0][int(radius),:])

# %%
x_axis = np.arange(len(PSF[0][0,:])/2) * scale
y_axis = PSF[0][int(radius),int(radius):]
plt.plot(x_axis,y_axis)

# %%
real_image = tifffile.imread("/home/georgeos/Storage/Dropbox (Cambridge University)/PhD_Georgeos_Hardo/ML_based_segmentation_results/40x_Ph2_test_1.5/top_trenches/trench_10/T_021.tif")
real_image[:]
plt.figure(figsize=(10,10))
plt.imshow(real_image,cmap=RFP_cmap)
real_image.shape
# Out:
# (330, 40)

# %%
sample = np.array(Image.open("/home/georgeos/Storage/Dropbox (Cambridge University)/PhD_Georgeos_Hardo/ML_based_segmentation_results/40x_Ph2_test_1.5/training_data/OPL_renders/OPL_intensity_900.tif"))
sample = sample[:,68:200]
sample = rescale_intensity(sample).astype(np.float64)
print(np.array(sample.shape)/3.3)
plt.figure(figsize=(10,10))
plt.imshow(sample,cmap=RFP_cmap)
plt.show()
# Out:
# [303.03030303  40.        ]

# %%
convolved = cp.asnumpy(cuconvolve(cp.array(sample),cp.array(PSF[0])))
background_signal = 500/6414 * convolved.max()
convolved  += background_signal
plt.figure(figsize=(10,10))
plt.imshow(convolved,cmap=RFP_cmap)
plt.show()

# %%
image_rescaled = rescale(convolved, 1/3.5, anti_aliasing=False)
image_rescaled = (rescale_intensity(image_rescaled).astype(np.float64)*255)
plt.figure(figsize=(10,10))
plt.imshow(image_rescaled,cmap=RFP_cmap)
plt.show()
image_rescaled.shape
# Out:
# (286, 38)

# %%
plt.figure(figsize=(10,10))
plt.imshow(real_image,cmap=RFP_cmap)

# %%
matched = match_histograms(image_rescaled, real_image, multichannel=False)

#noisy_img  = add_camera_noise(rescale_intensity(matched)*100,qe=0.8, sensitivity=92.88,
           #          dark_noise=0.29, bitdepth=16, baseline=100)

noisy_img = random_noise(rescale_intensity(matched), mode="poisson")

noisy_img = random_noise(rescale_intensity(matched), mode="gaussian", mean=0,var=0.002,clip=False)
noisy_img_matched = match_histograms(noisy_img, real_image, multichannel=False)

plt.figure(figsize=(10,10))
plt.imshow((noisy_img_matched),cmap=RFP_cmap)

# %%
real_stack = tifffile.imread("/home/georgeos/Documents/GitHub/SYMPTOMM2/prototyping/real_image_for_hist_match_stack.tif")

# %%
training_data_dir = "/home/georgeos/Storage/Dropbox (Cambridge University)/PhD_Georgeos_Hardo/ML_based_segmentation_results/40x_Ph2_test_1.5/training_data/OPL_renders/"

# %%
files = os.listdir(training_data_dir)
files.sort()
files
# Out:
# ['OPL_intensity_000.tif',
#  'OPL_intensity_001.tif',
#  'OPL_intensity_002.tif',
#  'OPL_intensity_003.tif',
#  'OPL_intensity_004.tif',
#  'OPL_intensity_005.tif',
#  'OPL_intensity_006.tif',
#  'OPL_intensity_007.tif',
#  'OPL_intensity_008.tif',
#  'OPL_intensity_009.tif',
#  'OPL_intensity_010.tif',
#  'OPL_intensity_011.tif',
#  'OPL_intensity_012.tif',
#  'OPL_intensity_013.tif',
#  'OPL_intensity_014.tif',
#  'OPL_intensity_015.tif',
#  'OPL_intensity_016.tif',
#  'OPL_intensity_017.tif',
#  'OPL_intensity_018.tif',
#  'OPL_intensity_019.tif',
#  'OPL_intensity_020.tif',
#  'OPL_intensity_021.tif',
#  'OPL_intensity_022.tif',
#  'OPL_intensity_023.tif',
#  'OPL_intensity_024.tif',
#  'OPL_intensity_025.tif',
#  'OPL_intensity_026.tif',
#  'OPL_intensity_027.tif',
#  'OPL_intensity_028.tif',
#  'OPL_intensity_029.tif',
#  'OPL_intensity_030.tif',
#  'OPL_intensity_031.tif',
#  'OPL_intensity_032.tif',
#  'OPL_intensity_033.tif',
#  'OPL_intensity_034.tif',
#  'OPL_intensity_035.tif',
#  'OPL_intensity_036.tif',
#  'OPL_intensity_037.tif',
#  'OPL_intensity_038.tif',
#  'OPL_intensity_039.tif',
#  'OPL_intensity_040.tif',
#  'OPL_intensity_041.tif',
#  'OPL_intensity_042.tif',
#  'OPL_intensity_043.tif',
#  'OPL_intensity_044.tif',
#  'OPL_intensity_045.tif',
#  'OPL_intensity_046.tif',
#  'OPL_intensity_047.tif',
#  'OPL_intensity_048.tif',
#  'OPL_intensity_049.tif',
#  'OPL_intensity_050.tif',
#  'OPL_intensity_051.tif',
#  'OPL_intensity_052.tif',
#  'OPL_intensity_053.tif',
#  'OPL_intensity_054.tif',
#  'OPL_intensity_055.tif',
#  'OPL_intensity_056.tif',
#  'OPL_intensity_057.tif',
#  'OPL_intensity_058.tif',
#  'OPL_intensity_059.tif',
#  'OPL_intensity_060.tif',
#  'OPL_intensity_061.tif',
#  'OPL_intensity_062.tif',
#  'OPL_intensity_063.tif',
#  'OPL_intensity_064.tif',
#  'OPL_intensity_065.tif',
#  'OPL_intensity_066.tif',
#  'OPL_intensity_067.tif',
#  'OPL_intensity_068.tif',
#  'OPL_intensity_069.tif',
#  'OPL_intensity_070.tif',
#  'OPL_intensity_071.tif',
#  'OPL_intensity_072.tif',
#  'OPL_intensity_073.tif',
#  'OPL_intensity_074.tif',
#  'OPL_intensity_075.tif',
#  'OPL_intensity_076.tif',
#  'OPL_intensity_077.tif',
#  'OPL_intensity_078.tif',
#  'OPL_intensity_079.tif',
#  'OPL_intensity_080.tif',
#  'OPL_intensity_081.tif',
#  'OPL_intensity_082.tif',
#  'OPL_intensity_083.tif',
#  'OPL_intensity_084.tif',
#  'OPL_intensity_085.tif',
#  'OPL_intensity_086.tif',
#  'OPL_intensity_087.tif',
#  'OPL_intensity_088.tif',
#  'OPL_intensity_089.tif',
#  'OPL_intensity_090.tif',
#  'OPL_intensity_091.tif',
#  'OPL_intensity_092.tif',
#  'OPL_intensity_093.tif',
#  'OPL_intensity_094.tif',
#  'OPL_intensity_095.tif',
#  'OPL_intensity_096.tif',
#  'OPL_intensity_097.tif',
#  'OPL_intensity_098.tif',
#  'OPL_intensity_099.tif',
#  'OPL_intensity_100.tif',
#  'OPL_intensity_1000.tif',
#  'OPL_intensity_1001.tif',
#  'OPL_intensity_1002.tif',
#  'OPL_intensity_1003.tif',
#  'OPL_intensity_1004.tif',
#  'OPL_intensity_1005.tif',
#  'OPL_intensity_1006.tif',
#  'OPL_intensity_1007.tif',
#  'OPL_intensity_1008.tif',
#  'OPL_intensity_1009.tif',
#  'OPL_intensity_101.tif',
#  'OPL_intensity_1010.tif',
#  'OPL_intensity_1011.tif',
#  'OPL_intensity_1012.tif',
#  'OPL_intensity_1013.tif',
#  'OPL_intensity_1014.tif',
#  'OPL_intensity_1015.tif',
#  'OPL_intensity_1016.tif',
#  'OPL_intensity_1017.tif',
#  'OPL_intensity_1018.tif',
#  'OPL_intensity_1019.tif',
#  'OPL_intensity_102.tif',
#  'OPL_intensity_1020.tif',
#  'OPL_intensity_1021.tif',
#  'OPL_intensity_1022.tif',
#  'OPL_intensity_1023.tif',
#  'OPL_intensity_1024.tif',
#  'OPL_intensity_1025.tif',
#  'OPL_intensity_1026.tif',
#  'OPL_intensity_1027.tif',
#  'OPL_intensity_1028.tif',
#  'OPL_intensity_1029.tif',
#  'OPL_intensity_103.tif',
#  'OPL_intensity_1030.tif',
#  'OPL_intensity_1031.tif',
#  'OPL_intensity_1032.tif',
#  'OPL_intensity_1033.tif',
#  'OPL_intensity_1034.tif',
#  'OPL_intensity_1035.tif',
#  'OPL_intensity_1036.tif',
#  'OPL_intensity_1037.tif',
#  'OPL_intensity_1038.tif',
#  'OPL_intensity_1039.tif',
#  'OPL_intensity_104.tif',
#  'OPL_intensity_1040.tif',
#  'OPL_intensity_1041.tif',
#  'OPL_intensity_1042.tif',
#  'OPL_intensity_1043.tif',
#  'OPL_intensity_1044.tif',
#  'OPL_intensity_1045.tif',
#  'OPL_intensity_1046.tif',
#  'OPL_intensity_1047.tif',
#  'OPL_intensity_1048.tif',
#  'OPL_intensity_1049.tif',
#  'OPL_intensity_105.tif',
#  'OPL_intensity_1050.tif',
#  'OPL_intensity_1051.tif',
#  'OPL_intensity_1052.tif',
#  'OPL_intensity_1053.tif',
#  'OPL_intensity_1054.tif',
#  'OPL_intensity_1055.tif',
#  'OPL_intensity_1056.tif',
#  'OPL_intensity_1057.tif',
#  'OPL_intensity_1058.tif',
#  'OPL_intensity_1059.tif',
#  'OPL_intensity_106.tif',
#  'OPL_intensity_1060.tif',
#  'OPL_intensity_1061.tif',
#  'OPL_intensity_1062.tif',
#  'OPL_intensity_1063.tif',
#  'OPL_intensity_1064.tif',
#  'OPL_intensity_1065.tif',
#  'OPL_intensity_1066.tif',
#  'OPL_intensity_1067.tif',
#  'OPL_intensity_1068.tif',
#  'OPL_intensity_1069.tif',
#  'OPL_intensity_107.tif',
#  'OPL_intensity_1070.tif',
#  'OPL_intensity_1071.tif',
#  'OPL_intensity_1072.tif',
#  'OPL_intensity_1073.tif',
#  'OPL_intensity_1074.tif',
#  'OPL_intensity_1075.tif',
#  'OPL_intensity_1076.tif',
#  'OPL_intensity_1077.tif',
#  'OPL_intensity_1078.tif',
#  'OPL_intensity_1079.tif',
#  'OPL_intensity_108.tif',
#  'OPL_intensity_1080.tif',
#  'OPL_intensity_1081.tif',
#  'OPL_intensity_1082.tif',
#  'OPL_intensity_1083.tif',
#  'OPL_intensity_1084.tif',
#  'OPL_intensity_1085.tif',
#  'OPL_intensity_1086.tif',
#  'OPL_intensity_1087.tif',
#  'OPL_intensity_1088.tif',
#  'OPL_intensity_1089.tif',
#  'OPL_intensity_109.tif',
#  'OPL_intensity_1090.tif',
#  'OPL_intensity_1091.tif',
#  'OPL_intensity_1092.tif',
#  'OPL_intensity_1093.tif',
#  'OPL_intensity_1094.tif',
#  'OPL_intensity_1095.tif',
#  'OPL_intensity_1096.tif',
#  'OPL_intensity_1097.tif',
#  'OPL_intensity_1098.tif',
#  'OPL_intensity_1099.tif',
#  'OPL_intensity_110.tif',
#  'OPL_intensity_1100.tif',
#  'OPL_intensity_1101.tif',
#  'OPL_intensity_1102.tif',
#  'OPL_intensity_1103.tif',
#  'OPL_intensity_1104.tif',
#  'OPL_intensity_1105.tif',
#  'OPL_intensity_1106.tif',
#  'OPL_intensity_1107.tif',
#  'OPL_intensity_1108.tif',
#  'OPL_intensity_1109.tif',
#  'OPL_intensity_111.tif',
#  'OPL_intensity_1110.tif',
#  'OPL_intensity_1111.tif',
#  'OPL_intensity_1112.tif',
#  'OPL_intensity_1113.tif',
#  'OPL_intensity_1114.tif',
#  'OPL_intensity_1115.tif',
#  'OPL_intensity_1116.tif',
#  'OPL_intensity_1117.tif',
#  'OPL_intensity_1118.tif',
#  'OPL_intensity_1119.tif',
#  'OPL_intensity_112.tif',
#  'OPL_intensity_1120.tif',
#  'OPL_intensity_1121.tif',
#  'OPL_intensity_1122.tif',
#  'OPL_intensity_1123.tif',
#  'OPL_intensity_1124.tif',
#  'OPL_intensity_1125.tif',
#  'OPL_intensity_1126.tif',
#  'OPL_intensity_1127.tif',
#  'OPL_intensity_1128.tif',
#  'OPL_intensity_1129.tif',
#  'OPL_intensity_113.tif',
#  'OPL_intensity_1130.tif',
#  'OPL_intensity_1131.tif',
#  'OPL_intensity_1132.tif',
#  'OPL_intensity_1133.tif',
#  'OPL_intensity_1134.tif',
#  'OPL_intensity_1135.tif',
#  'OPL_intensity_1136.tif',
#  'OPL_intensity_1137.tif',
#  'OPL_intensity_1138.tif',
#  'OPL_intensity_1139.tif',
#  'OPL_intensity_114.tif',
#  'OPL_intensity_1140.tif',
#  'OPL_intensity_1141.tif',
#  'OPL_intensity_1142.tif',
#  'OPL_intensity_1143.tif',
#  'OPL_intensity_1144.tif',
#  'OPL_intensity_1145.tif',
#  'OPL_intensity_1146.tif',
#  'OPL_intensity_1147.tif',
#  'OPL_intensity_1148.tif',
#  'OPL_intensity_1149.tif',
#  'OPL_intensity_115.tif',
#  'OPL_intensity_1150.tif',
#  'OPL_intensity_1151.tif',
#  'OPL_intensity_1152.tif',
#  'OPL_intensity_1153.tif',
#  'OPL_intensity_1154.tif',
#  'OPL_intensity_1155.tif',
#  'OPL_intensity_1156.tif',
#  'OPL_intensity_1157.tif',
#  'OPL_intensity_1158.tif',
#  'OPL_intensity_1159.tif',
#  'OPL_intensity_116.tif',
#  'OPL_intensity_1160.tif',
#  'OPL_intensity_1161.tif',
#  'OPL_intensity_1162.tif',
#  'OPL_intensity_1163.tif',
#  'OPL_intensity_1164.tif',
#  'OPL_intensity_1165.tif',
#  'OPL_intensity_1166.tif',
#  'OPL_intensity_1167.tif',
#  'OPL_intensity_1168.tif',
#  'OPL_intensity_1169.tif',
#  'OPL_intensity_117.tif',
#  'OPL_intensity_1170.tif',
#  'OPL_intensity_1171.tif',
#  'OPL_intensity_1172.tif',
#  'OPL_intensity_1173.tif',
#  'OPL_intensity_1174.tif',
#  'OPL_intensity_1175.tif',
#  'OPL_intensity_1176.tif',
#  'OPL_intensity_1177.tif',
#  'OPL_intensity_1178.tif',
#  'OPL_intensity_1179.tif',
#  'OPL_intensity_118.tif',
#  'OPL_intensity_1180.tif',
#  'OPL_intensity_1181.tif',
#  'OPL_intensity_1182.tif',
#  'OPL_intensity_1183.tif',
#  'OPL_intensity_1184.tif',
#  'OPL_intensity_1185.tif',
#  'OPL_intensity_1186.tif',
#  'OPL_intensity_1187.tif',
#  'OPL_intensity_1188.tif',
#  'OPL_intensity_1189.tif',
#  'OPL_intensity_119.tif',
#  'OPL_intensity_1190.tif',
#  'OPL_intensity_1191.tif',
#  'OPL_intensity_1192.tif',
#  'OPL_intensity_1193.tif',
#  'OPL_intensity_1194.tif',
#  'OPL_intensity_120.tif',
#  'OPL_intensity_121.tif',
#  'OPL_intensity_122.tif',
#  'OPL_intensity_123.tif',
#  'OPL_intensity_124.tif',
#  'OPL_intensity_125.tif',
#  'OPL_intensity_126.tif',
#  'OPL_intensity_127.tif',
#  'OPL_intensity_128.tif',
#  'OPL_intensity_129.tif',
#  'OPL_intensity_130.tif',
#  'OPL_intensity_131.tif',
#  'OPL_intensity_132.tif',
#  'OPL_intensity_133.tif',
#  'OPL_intensity_134.tif',
#  'OPL_intensity_135.tif',
#  'OPL_intensity_136.tif',
#  'OPL_intensity_137.tif',
#  'OPL_intensity_138.tif',
#  'OPL_intensity_139.tif',
#  'OPL_intensity_140.tif',
#  'OPL_intensity_141.tif',
#  'OPL_intensity_142.tif',
#  'OPL_intensity_143.tif',
#  'OPL_intensity_144.tif',
#  'OPL_intensity_145.tif',
#  'OPL_intensity_146.tif',
#  'OPL_intensity_147.tif',
#  'OPL_intensity_148.tif',
#  'OPL_intensity_149.tif',
#  'OPL_intensity_150.tif',
#  'OPL_intensity_151.tif',
#  'OPL_intensity_152.tif',
#  'OPL_intensity_153.tif',
#  'OPL_intensity_154.tif',
#  'OPL_intensity_155.tif',
#  'OPL_intensity_156.tif',
#  'OPL_intensity_157.tif',
#  'OPL_intensity_158.tif',
#  'OPL_intensity_159.tif',
#  'OPL_intensity_160.tif',
#  'OPL_intensity_161.tif',
#  'OPL_intensity_162.tif',
#  'OPL_intensity_163.tif',
#  'OPL_intensity_164.tif',
#  'OPL_intensity_165.tif',
#  'OPL_intensity_166.tif',
#  'OPL_intensity_167.tif',
#  'OPL_intensity_168.tif',
#  'OPL_intensity_169.tif',
#  'OPL_intensity_170.tif',
#  'OPL_intensity_171.tif',
#  'OPL_intensity_172.tif',
#  'OPL_intensity_173.tif',
#  'OPL_intensity_174.tif',
#  'OPL_intensity_175.tif',
#  'OPL_intensity_176.tif',
#  'OPL_intensity_177.tif',
#  'OPL_intensity_178.tif',
#  'OPL_intensity_179.tif',
#  'OPL_intensity_180.tif',
#  'OPL_intensity_181.tif',
#  'OPL_intensity_182.tif',
#  'OPL_intensity_183.tif',
#  'OPL_intensity_184.tif',
#  'OPL_intensity_185.tif',
#  'OPL_intensity_186.tif',
#  'OPL_intensity_187.tif',
#  'OPL_intensity_188.tif',
#  'OPL_intensity_189.tif',
#  'OPL_intensity_190.tif',
#  'OPL_intensity_191.tif',
#  'OPL_intensity_192.tif',
#  'OPL_intensity_193.tif',
#  'OPL_intensity_194.tif',
#  'OPL_intensity_195.tif',
#  'OPL_intensity_196.tif',
#  'OPL_intensity_197.tif',
#  'OPL_intensity_198.tif',
#  'OPL_intensity_199.tif',
#  'OPL_intensity_200.tif',
#  'OPL_intensity_2000.tif',
#  'OPL_intensity_2001.tif',
#  'OPL_intensity_2002.tif',
#  'OPL_intensity_2003.tif',
#  'OPL_intensity_2004.tif',
#  'OPL_intensity_2005.tif',
#  'OPL_intensity_2006.tif',
#  'OPL_intensity_2007.tif',
#  'OPL_intensity_2008.tif',
#  'OPL_intensity_2009.tif',
#  'OPL_intensity_201.tif',
#  'OPL_intensity_2010.tif',
#  'OPL_intensity_2011.tif',
#  'OPL_intensity_2012.tif',
#  'OPL_intensity_2013.tif',
#  'OPL_intensity_2014.tif',
#  'OPL_intensity_2015.tif',
#  'OPL_intensity_2016.tif',
#  'OPL_intensity_2017.tif',
#  'OPL_intensity_2018.tif',
#  'OPL_intensity_2019.tif',
#  'OPL_intensity_202.tif',
#  'OPL_intensity_2020.tif',
#  'OPL_intensity_2021.tif',
#  'OPL_intensity_2022.tif',
#  'OPL_intensity_2023.tif',
#  'OPL_intensity_2024.tif',
#  'OPL_intensity_2025.tif',
#  'OPL_intensity_2026.tif',
#  'OPL_intensity_2027.tif',
#  'OPL_intensity_2028.tif',
#  'OPL_intensity_2029.tif',
#  'OPL_intensity_203.tif',
#  'OPL_intensity_2030.tif',
#  'OPL_intensity_2031.tif',
#  'OPL_intensity_2032.tif',
#  'OPL_intensity_2033.tif',
#  'OPL_intensity_2034.tif',
#  'OPL_intensity_2035.tif',
#  'OPL_intensity_2036.tif',
#  'OPL_intensity_2037.tif',
#  'OPL_intensity_2038.tif',
#  'OPL_intensity_2039.tif',
#  'OPL_intensity_204.tif',
#  'OPL_intensity_2040.tif',
#  'OPL_intensity_2041.tif',
#  'OPL_intensity_2042.tif',
#  'OPL_intensity_2043.tif',
#  'OPL_intensity_2044.tif',
#  'OPL_intensity_2045.tif',
#  'OPL_intensity_2046.tif',
#  'OPL_intensity_2047.tif',
#  'OPL_intensity_2048.tif',
#  'OPL_intensity_2049.tif',
#  'OPL_intensity_205.tif',
#  'OPL_intensity_2050.tif',
#  'OPL_intensity_2051.tif',
#  'OPL_intensity_2052.tif',
#  'OPL_intensity_2053.tif',
#  'OPL_intensity_2054.tif',
#  'OPL_intensity_2055.tif',
#  'OPL_intensity_2056.tif',
#  'OPL_intensity_2057.tif',
#  'OPL_intensity_2058.tif',
#  'OPL_intensity_2059.tif',
#  'OPL_intensity_206.tif',
#  'OPL_intensity_2060.tif',
#  'OPL_intensity_2061.tif',
#  'OPL_intensity_2062.tif',
#  'OPL_intensity_2063.tif',
#  'OPL_intensity_2064.tif',
#  'OPL_intensity_2065.tif',
#  'OPL_intensity_2066.tif',
#  'OPL_intensity_2067.tif',
#  'OPL_intensity_2068.tif',
#  'OPL_intensity_2069.tif',
#  'OPL_intensity_207.tif',
#  'OPL_intensity_2070.tif',
#  'OPL_intensity_2071.tif',
#  'OPL_intensity_2072.tif',
#  'OPL_intensity_2073.tif',
#  'OPL_intensity_2074.tif',
#  'OPL_intensity_2075.tif',
#  'OPL_intensity_2076.tif',
#  'OPL_intensity_2077.tif',
#  'OPL_intensity_2078.tif',
#  'OPL_intensity_2079.tif',
#  'OPL_intensity_208.tif',
#  'OPL_intensity_2080.tif',
#  'OPL_intensity_2081.tif',
#  'OPL_intensity_2082.tif',
#  'OPL_intensity_2083.tif',
#  'OPL_intensity_2084.tif',
#  'OPL_intensity_2085.tif',
#  'OPL_intensity_2086.tif',
#  'OPL_intensity_2087.tif',
#  'OPL_intensity_2088.tif',
#  'OPL_intensity_2089.tif',
#  'OPL_intensity_209.tif',
#  'OPL_intensity_2090.tif',
#  'OPL_intensity_2091.tif',
#  'OPL_intensity_2092.tif',
#  'OPL_intensity_2093.tif',
#  'OPL_intensity_2094.tif',
#  'OPL_intensity_2095.tif',
#  'OPL_intensity_2096.tif',
#  'OPL_intensity_2097.tif',
#  'OPL_intensity_2098.tif',
#  'OPL_intensity_2099.tif',
#  'OPL_intensity_210.tif',
#  'OPL_intensity_2100.tif',
#  'OPL_intensity_2101.tif',
#  'OPL_intensity_2102.tif',
#  'OPL_intensity_2103.tif',
#  'OPL_intensity_2104.tif',
#  'OPL_intensity_2105.tif',
#  'OPL_intensity_2106.tif',
#  'OPL_intensity_2107.tif',
#  'OPL_intensity_2108.tif',
#  'OPL_intensity_2109.tif',
#  'OPL_intensity_211.tif',
#  'OPL_intensity_2110.tif',
#  'OPL_intensity_2111.tif',
#  'OPL_intensity_2112.tif',
#  'OPL_intensity_2113.tif',
#  'OPL_intensity_2114.tif',
#  'OPL_intensity_2115.tif',
#  'OPL_intensity_2116.tif',
#  'OPL_intensity_2117.tif',
#  'OPL_intensity_2118.tif',
#  'OPL_intensity_2119.tif',
#  'OPL_intensity_212.tif',
#  'OPL_intensity_2120.tif',
#  'OPL_intensity_2121.tif',
#  'OPL_intensity_2122.tif',
#  'OPL_intensity_2123.tif',
#  'OPL_intensity_2124.tif',
#  'OPL_intensity_2125.tif',
#  'OPL_intensity_2126.tif',
#  'OPL_intensity_2127.tif',
#  'OPL_intensity_2128.tif',
#  'OPL_intensity_2129.tif',
#  'OPL_intensity_213.tif',
#  'OPL_intensity_2130.tif',
#  'OPL_intensity_2131.tif',
#  'OPL_intensity_2132.tif',
#  'OPL_intensity_2133.tif',
#  'OPL_intensity_2134.tif',
#  'OPL_intensity_2135.tif',
#  'OPL_intensity_2136.tif',
#  'OPL_intensity_2137.tif',
#  'OPL_intensity_2138.tif',
#  'OPL_intensity_2139.tif',
#  'OPL_intensity_214.tif',
#  'OPL_intensity_2140.tif',
#  'OPL_intensity_2141.tif',
#  'OPL_intensity_2142.tif',
#  'OPL_intensity_2143.tif',
#  'OPL_intensity_2144.tif',
#  'OPL_intensity_2145.tif',
#  'OPL_intensity_2146.tif',
#  'OPL_intensity_2147.tif',
#  'OPL_intensity_2148.tif',
#  'OPL_intensity_2149.tif',
#  'OPL_intensity_215.tif',
#  'OPL_intensity_2150.tif',
#  'OPL_intensity_2151.tif',
#  'OPL_intensity_2152.tif',
#  'OPL_intensity_2153.tif',
#  'OPL_intensity_2154.tif',
#  'OPL_intensity_2155.tif',
#  'OPL_intensity_2156.tif',
#  'OPL_intensity_2157.tif',
#  'OPL_intensity_2158.tif',
#  'OPL_intensity_2159.tif',
#  'OPL_intensity_216.tif',
#  'OPL_intensity_2160.tif',
#  'OPL_intensity_2161.tif',
#  'OPL_intensity_2162.tif',
#  'OPL_intensity_2163.tif',
#  'OPL_intensity_2164.tif',
#  'OPL_intensity_2165.tif',
#  'OPL_intensity_2166.tif',
#  'OPL_intensity_2167.tif',
#  'OPL_intensity_2168.tif',
#  'OPL_intensity_2169.tif',
#  'OPL_intensity_217.tif',
#  'OPL_intensity_2170.tif',
#  'OPL_intensity_2171.tif',
#  'OPL_intensity_2172.tif',
#  'OPL_intensity_2173.tif',
#  'OPL_intensity_2174.tif',
#  'OPL_intensity_2175.tif',
#  'OPL_intensity_2176.tif',
#  'OPL_intensity_2177.tif',
#  'OPL_intensity_2178.tif',
#  'OPL_intensity_2179.tif',
#  'OPL_intensity_218.tif',
#  'OPL_intensity_2180.tif',
#  'OPL_intensity_2181.tif',
#  'OPL_intensity_2182.tif',
#  'OPL_intensity_2183.tif',
#  'OPL_intensity_2184.tif',
#  'OPL_intensity_2185.tif',
#  'OPL_intensity_2186.tif',
#  'OPL_intensity_2187.tif',
#  'OPL_intensity_2188.tif',
#  'OPL_intensity_2189.tif',
#  'OPL_intensity_219.tif',
#  'OPL_intensity_2190.tif',
#  'OPL_intensity_2191.tif',
#  'OPL_intensity_2192.tif',
#  'OPL_intensity_2193.tif',
#  'OPL_intensity_2194.tif',
#  'OPL_intensity_2195.tif',
#  'OPL_intensity_2196.tif',
#  'OPL_intensity_2197.tif',
#  'OPL_intensity_2198.tif',
#  'OPL_intensity_2199.tif',
#  'OPL_intensity_220.tif',
#  'OPL_intensity_2200.tif',
#  'OPL_intensity_2201.tif',
#  'OPL_intensity_2202.tif',
#  'OPL_intensity_2203.tif',
#  'OPL_intensity_2204.tif',
#  'OPL_intensity_2205.tif',
#  'OPL_intensity_2206.tif',
#  'OPL_intensity_2207.tif',
#  'OPL_intensity_2208.tif',
#  'OPL_intensity_2209.tif',
#  'OPL_intensity_221.tif',
#  'OPL_intensity_2210.tif',
#  'OPL_intensity_2211.tif',
#  'OPL_intensity_2212.tif',
#  'OPL_intensity_2213.tif',
#  'OPL_intensity_2214.tif',
#  'OPL_intensity_2215.tif',
#  'OPL_intensity_2216.tif',
#  'OPL_intensity_2217.tif',
#  'OPL_intensity_2218.tif',
#  'OPL_intensity_2219.tif',
#  'OPL_intensity_222.tif',
#  'OPL_intensity_2220.tif',
#  'OPL_intensity_2221.tif',
#  'OPL_intensity_2222.tif',
#  'OPL_intensity_2223.tif',
#  'OPL_intensity_2224.tif',
#  'OPL_intensity_2225.tif',
#  'OPL_intensity_2226.tif',
#  'OPL_intensity_2227.tif',
#  'OPL_intensity_2228.tif',
#  'OPL_intensity_2229.tif',
#  'OPL_intensity_223.tif',
#  'OPL_intensity_2230.tif',
#  'OPL_intensity_2231.tif',
#  'OPL_intensity_2232.tif',
#  'OPL_intensity_2233.tif',
#  'OPL_intensity_2234.tif',
#  'OPL_intensity_2235.tif',
#  'OPL_intensity_2236.tif',
#  'OPL_intensity_2237.tif',
#  'OPL_intensity_2238.tif',
#  'OPL_intensity_2239.tif',
#  'OPL_intensity_224.tif',
#  'OPL_intensity_2240.tif',
#  'OPL_intensity_2241.tif',
#  'OPL_intensity_2242.tif',
#  'OPL_intensity_2243.tif',
#  'OPL_intensity_2244.tif',
#  'OPL_intensity_2245.tif',
#  'OPL_intensity_2246.tif',
#  'OPL_intensity_2247.tif',
#  'OPL_intensity_2248.tif',
#  'OPL_intensity_2249.tif',
#  'OPL_intensity_225.tif',
#  'OPL_intensity_2250.tif',
#  'OPL_intensity_2251.tif',
#  'OPL_intensity_2252.tif',
#  'OPL_intensity_2253.tif',
#  'OPL_intensity_2254.tif',
#  'OPL_intensity_2255.tif',
#  'OPL_intensity_2256.tif',
#  'OPL_intensity_2257.tif',
#  'OPL_intensity_2258.tif',
#  'OPL_intensity_2259.tif',
#  'OPL_intensity_226.tif',
#  'OPL_intensity_2260.tif',
#  'OPL_intensity_2261.tif',
#  'OPL_intensity_2262.tif',
#  'OPL_intensity_2263.tif',
#  'OPL_intensity_2264.tif',
#  'OPL_intensity_2265.tif',
#  'OPL_intensity_2266.tif',
#  'OPL_intensity_2267.tif',
#  'OPL_intensity_2268.tif',
#  'OPL_intensity_2269.tif',
#  'OPL_intensity_227.tif',
#  'OPL_intensity_2270.tif',
#  'OPL_intensity_2271.tif',
#  'OPL_intensity_2272.tif',
#  'OPL_intensity_2273.tif',
#  'OPL_intensity_2274.tif',
#  'OPL_intensity_2275.tif',
#  'OPL_intensity_2276.tif',
#  'OPL_intensity_2277.tif',
#  'OPL_intensity_2278.tif',
#  'OPL_intensity_2279.tif',
#  'OPL_intensity_228.tif',
#  'OPL_intensity_2280.tif',
#  'OPL_intensity_2281.tif',
#  'OPL_intensity_2282.tif',
#  'OPL_intensity_2283.tif',
#  'OPL_intensity_2284.tif',
#  'OPL_intensity_2285.tif',
#  'OPL_intensity_2286.tif',
#  'OPL_intensity_2287.tif',
#  'OPL_intensity_2288.tif',
#  'OPL_intensity_2289.tif',
#  'OPL_intensity_229.tif',
#  'OPL_intensity_2290.tif',
#  'OPL_intensity_2291.tif',
#  'OPL_intensity_2292.tif',
#  'OPL_intensity_2293.tif',
#  'OPL_intensity_2294.tif',
#  'OPL_intensity_2295.tif',
#  'OPL_intensity_2296.tif',
#  'OPL_intensity_2297.tif',
#  'OPL_intensity_2298.tif',
#  'OPL_intensity_2299.tif',
#  'OPL_intensity_230.tif',
#  'OPL_intensity_2300.tif',
#  'OPL_intensity_2301.tif',
#  'OPL_intensity_2302.tif',
#  'OPL_intensity_2303.tif',
#  'OPL_intensity_2304.tif',
#  'OPL_intensity_2305.tif',
#  'OPL_intensity_2306.tif',
#  'OPL_intensity_2307.tif',
#  'OPL_intensity_2308.tif',
#  'OPL_intensity_2309.tif',
#  'OPL_intensity_231.tif',
#  'OPL_intensity_2310.tif',
#  'OPL_intensity_2311.tif',
#  'OPL_intensity_2312.tif',
#  'OPL_intensity_2313.tif',
#  'OPL_intensity_2314.tif',
#  'OPL_intensity_2315.tif',
#  'OPL_intensity_2316.tif',
#  'OPL_intensity_2317.tif',
#  'OPL_intensity_2318.tif',
#  'OPL_intensity_2319.tif',
#  'OPL_intensity_232.tif',
#  'OPL_intensity_2320.tif',
#  'OPL_intensity_2321.tif',
#  'OPL_intensity_2322.tif',
#  'OPL_intensity_2323.tif',
#  'OPL_intensity_2324.tif',
#  'OPL_intensity_2325.tif',
#  'OPL_intensity_2326.tif',
#  'OPL_intensity_2327.tif',
#  'OPL_intensity_2328.tif',
#  'OPL_intensity_2329.tif',
#  'OPL_intensity_233.tif',
#  'OPL_intensity_2330.tif',
#  'OPL_intensity_2331.tif',
#  'OPL_intensity_2332.tif',
#  'OPL_intensity_2333.tif',
#  'OPL_intensity_2334.tif',
#  'OPL_intensity_2335.tif',
#  'OPL_intensity_2336.tif',
#  'OPL_intensity_2337.tif',
#  'OPL_intensity_2338.tif',
#  'OPL_intensity_2339.tif',
#  'OPL_intensity_234.tif',
#  'OPL_intensity_2340.tif',
#  'OPL_intensity_2341.tif',
#  'OPL_intensity_2342.tif',
#  'OPL_intensity_2343.tif',
#  'OPL_intensity_2344.tif',
#  'OPL_intensity_2345.tif',
#  'OPL_intensity_2346.tif',
#  'OPL_intensity_2347.tif',
#  'OPL_intensity_2348.tif',
#  'OPL_intensity_2349.tif',
#  'OPL_intensity_235.tif',
#  'OPL_intensity_2350.tif',
#  'OPL_intensity_2351.tif',
#  'OPL_intensity_2352.tif',
#  'OPL_intensity_2353.tif',
#  'OPL_intensity_2354.tif',
#  'OPL_intensity_2355.tif',
#  'OPL_intensity_2356.tif',
#  'OPL_intensity_2357.tif',
#  'OPL_intensity_2358.tif',
#  'OPL_intensity_2359.tif',
#  'OPL_intensity_236.tif',
#  'OPL_intensity_2360.tif',
#  'OPL_intensity_2361.tif',
#  'OPL_intensity_2362.tif',
#  'OPL_intensity_2363.tif',
#  'OPL_intensity_2364.tif',
#  'OPL_intensity_2365.tif',
#  'OPL_intensity_2366.tif',
#  'OPL_intensity_2367.tif',
#  'OPL_intensity_2368.tif',
#  'OPL_intensity_2369.tif',
#  'OPL_intensity_237.tif',
#  'OPL_intensity_2370.tif',
#  'OPL_intensity_2371.tif',
#  'OPL_intensity_2372.tif',
#  'OPL_intensity_2373.tif',
#  'OPL_intensity_2374.tif',
#  'OPL_intensity_2375.tif',
#  'OPL_intensity_2376.tif',
#  'OPL_intensity_2377.tif',
#  'OPL_intensity_2378.tif',
#  'OPL_intensity_2379.tif',
#  'OPL_intensity_238.tif',
#  'OPL_intensity_2380.tif',
#  'OPL_intensity_2381.tif',
#  'OPL_intensity_2382.tif',
#  'OPL_intensity_2383.tif',
#  'OPL_intensity_2384.tif',
#  'OPL_intensity_2385.tif',
#  'OPL_intensity_2386.tif',
#  'OPL_intensity_2387.tif',
#  'OPL_intensity_2388.tif',
#  'OPL_intensity_2389.tif',
#  'OPL_intensity_239.tif',
#  'OPL_intensity_2390.tif',
#  'OPL_intensity_2391.tif',
#  'OPL_intensity_2392.tif',
#  'OPL_intensity_2393.tif',
#  'OPL_intensity_2394.tif',
#  'OPL_intensity_2395.tif',
#  'OPL_intensity_2396.tif',
#  'OPL_intensity_2397.tif',
#  'OPL_intensity_2398.tif',
#  'OPL_intensity_240.tif',
#  'OPL_intensity_241.tif',
#  'OPL_intensity_242.tif',
#  'OPL_intensity_243.tif',
#  'OPL_intensity_244.tif',
#  'OPL_intensity_245.tif',
#  'OPL_intensity_246.tif',
#  'OPL_intensity_247.tif',
#  'OPL_intensity_248.tif',
#  'OPL_intensity_249.tif',
#  'OPL_intensity_250.tif',
#  'OPL_intensity_251.tif',
#  'OPL_intensity_252.tif',
#  'OPL_intensity_253.tif',
#  'OPL_intensity_254.tif',
#  'OPL_intensity_255.tif',
#  'OPL_intensity_256.tif',
#  'OPL_intensity_257.tif',
#  'OPL_intensity_258.tif',
#  'OPL_intensity_259.tif',
#  'OPL_intensity_260.tif',
#  'OPL_intensity_261.tif',
#  'OPL_intensity_262.tif',
#  'OPL_intensity_263.tif',
#  'OPL_intensity_264.tif',
#  'OPL_intensity_265.tif',
#  'OPL_intensity_266.tif',
#  'OPL_intensity_267.tif',
#  'OPL_intensity_268.tif',
#  'OPL_intensity_269.tif',
#  'OPL_intensity_270.tif',
#  'OPL_intensity_271.tif',
#  'OPL_intensity_272.tif',
#  'OPL_intensity_273.tif',
#  'OPL_intensity_274.tif',
#  'OPL_intensity_275.tif',
#  'OPL_intensity_276.tif',
#  'OPL_intensity_277.tif',
#  'OPL_intensity_278.tif',
#  'OPL_intensity_279.tif',
#  'OPL_intensity_280.tif',
#  'OPL_intensity_281.tif',
#  'OPL_intensity_282.tif',
#  'OPL_intensity_283.tif',
#  'OPL_intensity_284.tif',
#  'OPL_intensity_285.tif',
#  'OPL_intensity_286.tif',
#  'OPL_intensity_287.tif',
#  'OPL_intensity_288.tif',
#  'OPL_intensity_289.tif',
#  'OPL_intensity_290.tif',
#  'OPL_intensity_291.tif',
#  'OPL_intensity_292.tif',
#  'OPL_intensity_293.tif',
#  'OPL_intensity_294.tif',
#  'OPL_intensity_295.tif',
#  'OPL_intensity_296.tif',
#  'OPL_intensity_297.tif',
#  'OPL_intensity_298.tif',
#  'OPL_intensity_299.tif',
#  'OPL_intensity_300.tif',
#  'OPL_intensity_3000.tif',
#  'OPL_intensity_3001.tif',
#  'OPL_intensity_3002.tif',
#  'OPL_intensity_3003.tif',
#  'OPL_intensity_3004.tif',
#  'OPL_intensity_3005.tif',
#  'OPL_intensity_3006.tif',
#  'OPL_intensity_3007.tif',
#  'OPL_intensity_3008.tif',
#  'OPL_intensity_3009.tif',
#  'OPL_intensity_301.tif',
#  'OPL_intensity_3010.tif',
#  'OPL_intensity_3011.tif',
#  'OPL_intensity_3012.tif',
#  'OPL_intensity_3013.tif',
#  'OPL_intensity_3014.tif',
#  'OPL_intensity_3015.tif',
#  'OPL_intensity_3016.tif',
#  'OPL_intensity_3017.tif',
#  'OPL_intensity_3018.tif',
#  'OPL_intensity_3019.tif',
#  'OPL_intensity_302.tif',
#  'OPL_intensity_3020.tif',
#  'OPL_intensity_3021.tif',
#  'OPL_intensity_3022.tif',
#  'OPL_intensity_3023.tif',
#  'OPL_intensity_3024.tif',
#  'OPL_intensity_3025.tif',
#  'OPL_intensity_3026.tif',
#  'OPL_intensity_3027.tif',
#  'OPL_intensity_3028.tif',
#  'OPL_intensity_3029.tif',
#  'OPL_intensity_303.tif',
#  'OPL_intensity_3030.tif',
#  'OPL_intensity_3031.tif',
#  'OPL_intensity_3032.tif',
#  'OPL_intensity_3033.tif',
#  'OPL_intensity_3034.tif',
#  'OPL_intensity_3035.tif',
#  'OPL_intensity_3036.tif',
#  'OPL_intensity_3037.tif',
#  'OPL_intensity_3038.tif',
#  'OPL_intensity_3039.tif',
#  'OPL_intensity_304.tif',
#  'OPL_intensity_3040.tif',
#  'OPL_intensity_3041.tif',
#  'OPL_intensity_3042.tif',
#  'OPL_intensity_3043.tif',
#  'OPL_intensity_3044.tif',
#  'OPL_intensity_3045.tif',
#  'OPL_intensity_3046.tif',
#  'OPL_intensity_3047.tif',
#  'OPL_intensity_3048.tif',
#  'OPL_intensity_3049.tif',
#  'OPL_intensity_305.tif',
#  'OPL_intensity_3050.tif',
#  'OPL_intensity_3051.tif',
#  'OPL_intensity_3052.tif',
#  'OPL_intensity_3053.tif',
#  'OPL_intensity_3054.tif',
#  'OPL_intensity_3055.tif',
#  'OPL_intensity_3056.tif',
#  'OPL_intensity_3057.tif',
#  'OPL_intensity_3058.tif',
#  'OPL_intensity_3059.tif',
#  'OPL_intensity_306.tif',
#  'OPL_intensity_3060.tif',
#  'OPL_intensity_3061.tif',
#  'OPL_intensity_3062.tif',
#  'OPL_intensity_3063.tif',
#  'OPL_intensity_3064.tif',
#  'OPL_intensity_3065.tif',
#  'OPL_intensity_3066.tif',
#  'OPL_intensity_3067.tif',
#  'OPL_intensity_3068.tif',
#  'OPL_intensity_3069.tif',
#  'OPL_intensity_307.tif',
#  'OPL_intensity_3070.tif',
#  'OPL_intensity_3071.tif',
#  'OPL_intensity_3072.tif',
#  'OPL_intensity_3073.tif',
#  'OPL_intensity_3074.tif',
#  'OPL_intensity_3075.tif',
#  'OPL_intensity_3076.tif',
#  'OPL_intensity_3077.tif',
#  'OPL_intensity_3078.tif',
#  'OPL_intensity_3079.tif',
#  'OPL_intensity_308.tif',
#  'OPL_intensity_3080.tif',
#  'OPL_intensity_3081.tif',
#  'OPL_intensity_3082.tif',
#  'OPL_intensity_3083.tif',
#  'OPL_intensity_3084.tif',
#  'OPL_intensity_3085.tif',
#  'OPL_intensity_3086.tif',
#  'OPL_intensity_3087.tif',
#  'OPL_intensity_3088.tif',
#  'OPL_intensity_3089.tif',
#  'OPL_intensity_309.tif',
#  'OPL_intensity_3090.tif',
#  'OPL_intensity_3091.tif',
#  'OPL_intensity_3092.tif',
#  'OPL_intensity_3093.tif',
#  'OPL_intensity_3094.tif',
#  'OPL_intensity_3095.tif',
#  ...]

# %%
samples = files[:int(len(files)/2)]
masks = files[int(len(files)/2):]

# %%
_ = np.random.randint(0, len(files)/2-1)
print(masks[_])
print(samples[_])
# Out:
# OPL_mask_397.tif
# OPL_intensity_397.tif

# %%
training_data_dir+samples[0]
# Out:
# '/home/georgeos/Storage/Dropbox (Cambridge University)/PhD_Georgeos_Hardo/ML_based_segmentation_results/40x_Ph2_test_1.5/training_data/OPL_renders/OPL_intensity_000.tif'

# %%
## main loop

for x in range(int(len(files)/2)):
    sample = np.array(Image.open(training_data_dir+samples[x]))
    sample = sample[:,68:200]
    sample = rescale_intensity(sample).astype(np.float64)
    convolved = cp.asnumpy(cuconvolve(cp.array(sample),cp.array(PSF[0])))
    background_signal = 500/6414 * convolved.max()
    convolved  += background_signal
    image_rescaled = rescale(convolved, 1/4.5, anti_aliasing=False)
    image_rescaled = (rescale_intensity(image_rescaled).astype(np.float64)*255)
    
    matched = match_histograms(image_rescaled, real_image, multichannel=False)
    noisy_img = random_noise(rescale_intensity(matched), mode="gaussian", mean=5,var=0.0005,clip=False)

    noisy_img_matched = match_histograms(noisy_img, real_image, multichannel=False)
    im = Image.fromarray(skimage.img_as_uint(rescale_intensity(noisy_img_matched)))
    im.save("/home/georgeos/Storage/Dropbox (Cambridge University)/PhD_Georgeos_Hardo/ML_based_segmentation_results/40x_Ph2_test_1.5/training_data/convolutions/synth_{}.tif".format(str(x).zfill(3)))

# %%
for x in range(int(len(files)/2)):
    sample = np.array(Image.open(training_data_dir+masks[x]))
    sample = sample[:,68:200]
    sample = opening(sample,np.ones((5,15)))
    sample = sample.astype(np.bool_)
    image_rescaled = rescale(sample, 1/4.5, anti_aliasing=False, preserve_range=True, clip=True,mode="constant")
    im = Image.fromarray(image_rescaled)
    im.save("/home/georgeos/Storage/Dropbox (Cambridge University)/PhD_Georgeos_Hardo/ML_based_segmentation_results/40x_Ph2_test_1.5/training_data/masks/synth_{}.tif".format(str(x).zfill(3)))

# %%
type(sample)
