# %%
import pickle

# %%
with open("output_pickles/cell_timeseries.p", "rb") as f:
    cell_timeseries = pickle.load(f)

# %%
cell_timeseries
# Out:
# [[<SYMPTOMM.cell.Cell at 0x7facddd38b80>,
# ...
# ...
# ...
#  ...]
