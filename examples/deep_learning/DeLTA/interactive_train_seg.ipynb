# %%
'''
This script trains the cell segmentation U-Net

@author: jblugagne
Small augmentations: georgeoshardo
'''
# pip install "scikit_image==0.16.2"
from SyMBac.external.DeLTA.model import unet_seg
from SyMBac.external.DeLTA.data import trainGenerator_seg
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf
from glob import glob
from natsort import natsorted
# Files:

# %%
DeLTA_data =  "/home/georgeos/Storage/Dropbox/Dropbox (Cambridge University)/Phase/DeLTA_new_training_data_hist_fourier_mixed/"

training_set = DeLTA_data
model_file = DeLTA_data + 'models/test_new_saved-model-{epoch:02d}.hdf5' #'/unet.hdf5'

# Parameters:
target_size = (256,48)
input_size = target_size + (1,)
batch_size = 10
epochs = 400
steps_per_epoch = 250

#Data generator:
data_gen_args = dict(
                    rotation = 0.5,
                    shiftX=.08,
                    shiftY=.08,
                    zoom=.17,
                    horizontal_flip=True,
                    histogram_voodoo=True,
                    illumination_voodoo=True)

myGene = trainGenerator_seg(batch_size,
                           training_set + 'preprocessed/CROPPED_FILTERED/',
                           training_set + 'preprocessed/CROPPED_MASKS/',
                           training_set + 'preprocessed/WEIGHTMAPS/',
                           augment_params = data_gen_args,
                           target_size = target_size)


# Define model:
model = unet_seg(input_size = input_size)
model.summary()
model_checkpoint = ModelCheckpoint(model_file, monitor='loss',verbose=1, save_best_only=False)

#filepath = "saved-model-{epoch:02d}-{loss:.2f}.hdf5"
# Train it:
model.fit_generator(myGene,steps_per_epoch=steps_per_epoch,epochs=epochs,callbacks=[model_checkpoint])
# Out:
# 2021-10-25 19:02:48.272190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 19:02:48.302466: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 19:02:48.302864: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 19:02:48.303668: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-25 19:02:48.304266: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 19:02:48.304587: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 19:02:48.304819: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 19:02:48.986075: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 19:02:48.986357: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 19:02:48.986592: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 19:02:48.987006: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4638 MB memory:  -> device: 0, name: Quadro RTX 3000, pci bus id: 0000:01:00.0, compute capability: 7.5
# /home/georgeos/anaconda3/envs/SyMBac/lib/python3.9/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# /home/georgeos/anaconda3/envs/SyMBac/lib/python3.9/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# true_input (InputLayer)         [(None, 256, 48, 1)] 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 48, 64)  640         true_input[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 48, 64)  36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 24, 64)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 24, 128) 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 24, 128) 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 12, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 12, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 12, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 6, 256)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 6, 512)   1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 6, 512)   2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 6, 512)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 3, 512)   0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 3, 1024)  4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 3, 1024)  9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 3, 1024)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 6, 1024)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 6, 512)   2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 6, 1024)  0           dropout[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 6, 512)   4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 6, 512)   2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 12, 512)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 12, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 12, 512)  0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 12, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 12, 256)  590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 24, 256) 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 24, 128) 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 24, 256) 0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 24, 128) 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 24, 128) 147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 48, 128) 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 48, 64)  32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 48, 128) 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 48, 64)  73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 48, 64)  36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# true_output (Conv2D)            (None, 256, 48, 1)   65          conv2d_21[0][0]
# ==================================================================================================
# Total params: 31,030,593
# Trainable params: 31,030,593
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /home/georgeos/anaconda3/envs/SyMBac/lib/python3.9/site-packages/SyMBac/external/DeLTA/data.py:91: FutureWarning: Input image dtype is bool. Gaussian convolution is not defined with bool data type. Please set anti_aliasing to False or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   i = trans.resize(i, target_size, anti_aliasing=True, order=order)
# 2021-10-25 19:02:49.554811: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/400
# 2021-10-25 19:02:51.292626: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8201
# 2021-10-25 19:02:52.125136: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 250/250 [==============================] - 42s 142ms/step - loss: 8.6171e-04 - unstack_acc: 0.9282
#
# Epoch 00001: saving model to /home/georgeos/Storage/Dropbox/Dropbox (Cambridge University)/Phase/DeLTA_new_training_data_hist_fourier_mixed/models/test_new_saved-model-01.hdf5
# Epoch 2/400
# 250/250 [==============================] - 36s 143ms/step - loss: 4.6304e-04 - unstack_acc: 0.9585
#
# Epoch 00002: saving model to /home/georgeos/Storage/Dropbox/Dropbox (Cambridge University)/Phase/DeLTA_new_training_data_hist_fourier_mixed/models/test_new_saved-model-02.hdf5
# Epoch 3/400
# 250/250 [==============================] - 36s 143ms/step - loss: 3.8766e-04 - unstack_acc: 0.9635
#
# Epoch 00003: saving model to /home/georgeos/Storage/Dropbox/Dropbox (Cambridge University)/Phase/DeLTA_new_training_data_hist_fourier_mixed/models/test_new_saved-model-03.hdf5
# Epoch 4/400
# 250/250 [==============================] - 36s 144ms/step - loss: 3.5086e-04 - unstack_acc: 0.9666
#
# Epoch 00004: saving model to /home/georgeos/Storage/Dropbox/Dropbox (Cambridge University)/Phase/DeLTA_new_training_data_hist_fourier_mixed/models/test_new_saved-model-04.hdf5
# Epoch 5/400
# 250/250 [==============================] - 36s 144ms/step - loss: 3.3605e-04 - unstack_acc: 0.9680
#
# Epoch 00005: saving model to /home/georgeos/Storage/Dropbox/Dropbox (Cambridge University)/Phase/DeLTA_new_training_data_hist_fourier_mixed/models/test_new_saved-model-05.hdf5
# Epoch 6/400
# 250/250 [==============================] - 36s 144ms/step - loss: 3.2273e-04 - unstack_acc: 0.9692
#
# Epoch 00006: saving model to /home/georgeos/Storage/Dropbox/Dropbox (Cambridge University)/Phase/DeLTA_new_training_data_hist_fourier_mixed/models/test_new_saved-model-06.hdf5
# Epoch 7/400
# 250/250 [==============================] - 36s 144ms/step - loss: 3.0155e-04 - unstack_acc: 0.9709
#
# Epoch 00007: saving model to /home/georgeos/Storage/Dropbox/Dropbox (Cambridge University)/Phase/DeLTA_new_training_data_hist_fourier_mixed/models/test_new_saved-model-07.hdf5
# Epoch 8/400
# 250/250 [==============================] - 36s 144ms/step - loss: 2.8710e-04 - unstack_acc: 0.9720
#
# Epoch 00008: saving model to /home/georgeos/Storage/Dropbox/Dropbox (Cambridge University)/Phase/DeLTA_new_training_data_hist_fourier_mixed/models/test_new_saved-model-08.hdf5
# Epoch 9/400
# 250/250 [==============================] - 36s 144ms/step - loss: 2.8521e-04 - unstack_acc: 0.9722
#
# Epoch 00009: saving model to /home/georgeos/Storage/Dropbox/Dropbox (Cambridge University)/Phase/DeLTA_new_training_data_hist_fourier_mixed/models/test_new_saved-model-09.hdf5
# Epoch 10/400
# 250/250 [==============================] - 36s 144ms/step - loss: 2.8711e-04 - unstack_acc: 0.9722
#
# Epoch 00010: saving model to /home/georgeos/Storage/Dropbox/Dropbox (Cambridge University)/Phase/DeLTA_new_training_data_hist_fourier_mixed/models/test_new_saved-model-10.hdf5
# Epoch 11/400
# 250/250 [==============================] - 36s 144ms/step - loss: 2.7648e-04 - unstack_acc: 0.9732
#
# Epoch 00011: saving model to /home/georgeos/Storage/Dropbox/Dropbox (Cambridge University)/Phase/DeLTA_new_training_data_hist_fourier_mixed/models/test_new_saved-model-11.hdf5
# Epoch 12/400
# 250/250 [==============================] - 36s 145ms/step - loss: 2.7038e-04 - unstack_acc: 0.9736
#
# Epoch 00012: saving model to /home/georgeos/Storage/Dropbox/Dropbox (Cambridge University)/Phase/DeLTA_new_training_data_hist_fourier_mixed/models/test_new_saved-model-12.hdf5
# Epoch 13/400
# 250/250 [==============================] - 36s 145ms/step - loss: 2.6759e-04 - unstack_acc: 0.9738
#
# Epoch 00013: saving model to /home/georgeos/Storage/Dropbox/Dropbox (Cambridge University)/Phase/DeLTA_new_training_data_hist_fourier_mixed/models/test_new_saved-model-13.hdf5
# Epoch 14/400
# 213/250 [========================>.....] - ETA: 5s - loss: 2.6826e-04 - unstack_acc: 0.9740
