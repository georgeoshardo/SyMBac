# %%
'''
This script trains the cell segmentation U-Net

@author: jblugagne
Small augmentations: georgeoshardo
'''
# pip install "scikit_image==0.16.2"
#conda install -c conda-forge tensorflow-gpu=1.15
from SyMBac.external.DeLTA.model import unet_seg
from SyMBac.external.DeLTA.data import trainGenerator_seg
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf
from random import shuffle
import glob
import os
import random
from shutil import copyfile, rmtree

# %%
DeLTA_data =  "/home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/"

training_set = DeLTA_data
model_file = DeLTA_data + 'models/saved-model-varnum-{number:02d}.hdf5' #'/unet.hdf5'

# %%
img_path = training_set+'preprocessed/CROPPED_FILTERED/'
mask_path = training_set+'preprocessed/CROPPED_MASKS/'
weight_path = training_set + 'preprocessed/WEIGHTMAPS/'

# %%
temp_store = "/home/georgeos/Storage/Dropbox (Cambridge University)/Phase/temp/"
try:
    os.mkdir(temp_store)
except:
    pass
img_path_tmp = temp_store+'/CROPPED_FILTERED/'
mask_path_tmp = temp_store+'/CROPPED_MASKS/'
weight_path_tmp = temp_store + '/WEIGHTMAPS/'

try:
    os.mkdir(img_path_tmp)
    os.mkdir(mask_path_tmp)
    os.mkdir(weight_path_tmp)
except:
    pass

# %%
try:
    rmtree(img_path_tmp)
    rmtree(mask_path_tmp)
    rmtree(weight_path_tmp)
except:
    pass

# %%
2000*0.0005
# Out:
# 1.0

# %%
for frac in [0.0005,0.001,0.005, 0.01, 0.1, 0.2, 0.5, 0.75, 0.9]:
    os.mkdir(img_path_tmp)
    os.mkdir(mask_path_tmp)
    os.mkdir(weight_path_tmp)
    training_image_names = os.listdir(img_path)
    shuffle(training_image_names)
    sample_amount = int(frac*len(training_image_names))
    sample = training_image_names[:sample_amount]

    for perm_path, tmp_path in zip([img_path, mask_path, weight_path],[img_path_tmp,mask_path_tmp,weight_path_tmp]):
        copy_from = [perm_path + img_name for img_name in sample]
        copy_to = [tmp_path + img_name for img_name in sample]
        for frm, to in zip(copy_from, copy_to):
            copyfile(frm,to)


    model_file = DeLTA_data + 'models/saved-model-frac-{}.hdf5'.format(frac) #'/unet.hdf5'
    # Parameters:
    target_size = (192,32)
    input_size = target_size + (1,)
    batch_size = 10
    epochs = 15
    steps_per_epoch = 250

    #Data generator:
    data_gen_args = dict(
                        rotation = 0.5,
                        shiftX=.08,
                        shiftY=.08,
                        zoom=.17,
                        horizontal_flip=True,
                        histogram_voodoo=True,
                        illumination_voodoo=True)

    myGene = trainGenerator_seg(batch_size,
                               img_path_tmp,
                               mask_path_tmp,
                               weight_path_tmp,
                               augment_params = data_gen_args,
                               target_size = target_size)


    # Define model:
    model = unet_seg(input_size = input_size)
    model.summary()
    model_checkpoint = ModelCheckpoint(model_file, monitor='loss',verbose=1, save_best_only=False)

    #filepath = "saved-model-{epoch:02d}-{loss:.2f}.hdf5"
    # Train it:
    model.fit_generator(myGene,steps_per_epoch=steps_per_epoch,epochs=epochs,callbacks=[model_checkpoint])

    rmtree(img_path_tmp)
    rmtree(mask_path_tmp)
    rmtree(weight_path_tmp)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# true_input (InputLayer)         [(None, 192, 32, 1)] 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 192, 32, 64)  640         true_input[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 192, 32, 64)  36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 96, 16, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 96, 16, 128)  73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 96, 16, 128)  147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 48, 8, 128)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 48, 8, 256)   295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 48, 8, 256)   590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 24, 4, 256)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 24, 4, 512)   1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 24, 4, 512)   2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 24, 4, 512)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 2, 512)   0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 12, 2, 1024)  4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 12, 2, 1024)  9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 12, 2, 1024)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 24, 4, 1024)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 24, 4, 512)   2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 24, 4, 1024)  0           dropout[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 24, 4, 512)   4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 24, 4, 512)   2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 48, 8, 512)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 48, 8, 256)   524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 48, 8, 512)   0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 48, 8, 256)   1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 48, 8, 256)   590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 96, 16, 256)  0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 96, 16, 128)  131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 96, 16, 256)  0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 96, 16, 128)  295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 96, 16, 128)  147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 192, 32, 128) 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 192, 32, 64)  32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 192, 32, 128) 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 192, 32, 64)  73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 192, 32, 64)  36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# true_output (Conv2D)            (None, 192, 32, 1)   65          conv2d_21[0][0]
# ==================================================================================================
# Total params: 31,030,593
# Trainable params: 31,030,593
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/15
# /home/georgeos/anaconda3/envs/stardist-gpu/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta/data.py:91: FutureWarning: Input image dtype is bool. Gaussian convolution is not defined with bool data type. Please set anti_aliasing to False or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   i = trans.resize(i, target_size, anti_aliasing=True, order=order)
# 250/250 [==============================] - 25s 88ms/step - loss: 0.0013 - unstack_acc: 0.8729
#
# Epoch 00001: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.0005.hdf5
# Epoch 2/15
# 250/250 [==============================] - 22s 87ms/step - loss: 3.8837e-04 - unstack_acc: 0.9658
#
# Epoch 00002: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.0005.hdf5
# Epoch 3/15
# 250/250 [==============================] - 22s 87ms/step - loss: 3.1985e-04 - unstack_acc: 0.9701
#
# Epoch 00003: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.0005.hdf5
# Epoch 4/15
# 250/250 [==============================] - 22s 87ms/step - loss: 2.9171e-04 - unstack_acc: 0.9723
#
# Epoch 00004: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.0005.hdf5
# Epoch 5/15
# 250/250 [==============================] - 22s 88ms/step - loss: 2.7366e-04 - unstack_acc: 0.9736
#
# Epoch 00005: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.0005.hdf5
# Epoch 6/15
# 250/250 [==============================] - 22s 89ms/step - loss: 2.6795e-04 - unstack_acc: 0.9739
#
# Epoch 00006: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.0005.hdf5
# Epoch 7/15
# 250/250 [==============================] - 22s 88ms/step - loss: 2.5645e-04 - unstack_acc: 0.9749
#
# Epoch 00007: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.0005.hdf5
# Epoch 8/15
# 250/250 [==============================] - 22s 89ms/step - loss: 2.4962e-04 - unstack_acc: 0.9755
#
# Epoch 00008: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.0005.hdf5
# Epoch 9/15
# 250/250 [==============================] - 22s 88ms/step - loss: 2.4488e-04 - unstack_acc: 0.9761
#
# Epoch 00009: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.0005.hdf5
# Epoch 10/15
# 250/250 [==============================] - 22s 88ms/step - loss: 2.4484e-04 - unstack_acc: 0.9759
#
# Epoch 00010: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.0005.hdf5
# Epoch 11/15
# 250/250 [==============================] - 22s 89ms/step - loss: 2.3915e-04 - unstack_acc: 0.9764
#
# Epoch 00011: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.0005.hdf5
# Epoch 12/15
# 250/250 [==============================] - 22s 89ms/step - loss: 2.4331e-04 - unstack_acc: 0.9760
#
# Epoch 00012: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.0005.hdf5
# Epoch 13/15
# 250/250 [==============================] - 22s 89ms/step - loss: 2.4336e-04 - unstack_acc: 0.9761
#
# Epoch 00013: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.0005.hdf5
# Epoch 14/15
# 250/250 [==============================] - 22s 89ms/step - loss: 2.3440e-04 - unstack_acc: 0.9769
#
# Epoch 00014: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.0005.hdf5
# Epoch 15/15
# 250/250 [==============================] - 22s 89ms/step - loss: 2.4033e-04 - unstack_acc: 0.9763
#
# Epoch 00015: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.0005.hdf5
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# true_input (InputLayer)         [(None, 192, 32, 1)] 0
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 192, 32, 64)  640         true_input[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 192, 32, 64)  36928       conv2d_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 96, 16, 64)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 96, 16, 128)  73856       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 96, 16, 128)  147584      conv2d_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 48, 8, 128)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 48, 8, 256)   295168      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 48, 8, 256)   590080      conv2d_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 24, 4, 256)   0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 24, 4, 512)   1180160     max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 24, 4, 512)   2359808     conv2d_28[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 24, 4, 512)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 12, 2, 512)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 12, 2, 1024)  4719616     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 12, 2, 1024)  9438208     conv2d_30[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 12, 2, 1024)  0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 24, 4, 1024)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 24, 4, 512)   2097664     up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 24, 4, 1024)  0           dropout_2[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 24, 4, 512)   4719104     concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 24, 4, 512)   2359808     conv2d_33[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 48, 8, 512)   0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 48, 8, 256)   524544      up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 48, 8, 512)   0           conv2d_27[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 48, 8, 256)   1179904     concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 48, 8, 256)   590080      conv2d_36[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 96, 16, 256)  0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 96, 16, 128)  131200      up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 96, 16, 256)  0           conv2d_25[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 96, 16, 128)  295040      concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 96, 16, 128)  147584      conv2d_39[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 192, 32, 128) 0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 192, 32, 64)  32832       up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 192, 32, 128) 0           conv2d_23[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 192, 32, 64)  73792       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 192, 32, 64)  36928       conv2d_42[0][0]
# __________________________________________________________________________________________________
# true_output (Conv2D)            (None, 192, 32, 1)   65          conv2d_43[0][0]
# ==================================================================================================
# Total params: 31,030,593
# Trainable params: 31,030,593
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/15
# 250/250 [==============================] - 23s 89ms/step - loss: 9.5570e-04 - unstack_acc: 0.9104
#
# Epoch 00001: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.001.hdf5
# Epoch 2/15
# 250/250 [==============================] - 22s 90ms/step - loss: 3.2653e-04 - unstack_acc: 0.9677
#
# Epoch 00002: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.001.hdf5
# Epoch 3/15
# 250/250 [==============================] - 23s 91ms/step - loss: 2.7897e-04 - unstack_acc: 0.9710
#
# Epoch 00003: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.001.hdf5
# Epoch 4/15
# 250/250 [==============================] - 22s 90ms/step - loss: 2.5006e-04 - unstack_acc: 0.9735
#
# Epoch 00004: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.001.hdf5
# Epoch 5/15
# 250/250 [==============================] - 22s 90ms/step - loss: 2.2710e-04 - unstack_acc: 0.9756
#
# Epoch 00005: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.001.hdf5
# Epoch 6/15
# 250/250 [==============================] - 22s 90ms/step - loss: 2.3051e-04 - unstack_acc: 0.9753
#
# Epoch 00006: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.001.hdf5
# Epoch 7/15
# 250/250 [==============================] - 23s 90ms/step - loss: 2.1654e-04 - unstack_acc: 0.9766
#
# Epoch 00007: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.001.hdf5
# Epoch 8/15
# 250/250 [==============================] - 22s 90ms/step - loss: 2.1118e-04 - unstack_acc: 0.9771
#
# Epoch 00008: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.001.hdf5
# Epoch 9/15
# 250/250 [==============================] - 23s 90ms/step - loss: 2.0654e-04 - unstack_acc: 0.9777
#
# Epoch 00009: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.001.hdf5
# Epoch 10/15
# 250/250 [==============================] - 23s 91ms/step - loss: 2.0590e-04 - unstack_acc: 0.9776
#
# Epoch 00010: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.001.hdf5
# Epoch 11/15
# 250/250 [==============================] - 23s 90ms/step - loss: 1.9877e-04 - unstack_acc: 0.9782
#
# Epoch 00011: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.001.hdf5
# Epoch 12/15
# 250/250 [==============================] - 23s 91ms/step - loss: 1.9756e-04 - unstack_acc: 0.9783
#
# Epoch 00012: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.001.hdf5
# Epoch 13/15
# 250/250 [==============================] - 24s 98ms/step - loss: 2.0153e-04 - unstack_acc: 0.9782
#
# Epoch 00013: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.001.hdf5
# Epoch 14/15
# 250/250 [==============================] - 25s 99ms/step - loss: 2.0038e-04 - unstack_acc: 0.9785
#
# Epoch 00014: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.001.hdf5
# Epoch 15/15
# 250/250 [==============================] - 23s 93ms/step - loss: 1.9260e-04 - unstack_acc: 0.9791
#
# Epoch 00015: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.001.hdf5
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# true_input (InputLayer)         [(None, 192, 32, 1)] 0
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 192, 32, 64)  640         true_input[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 192, 32, 64)  36928       conv2d_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 96, 16, 64)   0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 96, 16, 128)  73856       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 96, 16, 128)  147584      conv2d_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 48, 8, 128)   0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 48, 8, 256)   295168      max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 48, 8, 256)   590080      conv2d_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 24, 4, 256)   0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 24, 4, 512)   1180160     max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 24, 4, 512)   2359808     conv2d_50[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 24, 4, 512)   0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 12, 2, 512)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 12, 2, 1024)  4719616     max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 12, 2, 1024)  9438208     conv2d_52[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 12, 2, 1024)  0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 24, 4, 1024)  0           dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 24, 4, 512)   2097664     up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 24, 4, 1024)  0           dropout_4[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 24, 4, 512)   4719104     concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 24, 4, 512)   2359808     conv2d_55[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 48, 8, 512)   0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 48, 8, 256)   524544      up_sampling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 48, 8, 512)   0           conv2d_49[0][0]
#                                                                  conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 48, 8, 256)   1179904     concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 48, 8, 256)   590080      conv2d_58[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 96, 16, 256)  0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 96, 16, 128)  131200      up_sampling2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 96, 16, 256)  0           conv2d_47[0][0]
#                                                                  conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 96, 16, 128)  295040      concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 96, 16, 128)  147584      conv2d_61[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 192, 32, 128) 0           conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 192, 32, 64)  32832       up_sampling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 192, 32, 128) 0           conv2d_45[0][0]
#                                                                  conv2d_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 192, 32, 64)  73792       concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 192, 32, 64)  36928       conv2d_64[0][0]
# __________________________________________________________________________________________________
# true_output (Conv2D)            (None, 192, 32, 1)   65          conv2d_65[0][0]
# ==================================================================================================
# Total params: 31,030,593
# Trainable params: 31,030,593
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/15
# 250/250 [==============================] - 26s 99ms/step - loss: 0.0012 - unstack_acc: 0.8900
#
# Epoch 00001: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.005.hdf5
# Epoch 2/15
# 250/250 [==============================] - 24s 97ms/step - loss: 4.3271e-04 - unstack_acc: 0.9608
#
# Epoch 00002: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.005.hdf5
# Epoch 3/15
# 250/250 [==============================] - 23s 92ms/step - loss: 3.7189e-04 - unstack_acc: 0.9640
#
# Epoch 00003: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.005.hdf5
# Epoch 4/15
# 250/250 [==============================] - 23s 94ms/step - loss: 3.3920e-04 - unstack_acc: 0.9661
#
# Epoch 00004: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.005.hdf5
# Epoch 5/15
# 250/250 [==============================] - 25s 99ms/step - loss: 3.1742e-04 - unstack_acc: 0.9680
#
# Epoch 00005: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.005.hdf5
# Epoch 6/15
# 250/250 [==============================] - 24s 97ms/step - loss: 2.9894e-04 - unstack_acc: 0.9695
#
# Epoch 00006: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.005.hdf5
# Epoch 7/15
# 250/250 [==============================] - 23s 92ms/step - loss: 2.8765e-04 - unstack_acc: 0.9707
#
# Epoch 00007: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.005.hdf5
# Epoch 8/15
# 250/250 [==============================] - 24s 95ms/step - loss: 2.8362e-04 - unstack_acc: 0.9709
#
# Epoch 00008: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.005.hdf5
# Epoch 9/15
# 250/250 [==============================] - 23s 92ms/step - loss: 2.7138e-04 - unstack_acc: 0.9723
#
# Epoch 00009: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.005.hdf5
# Epoch 10/15
# 250/250 [==============================] - 23s 92ms/step - loss: 2.6165e-04 - unstack_acc: 0.9730
#
# Epoch 00010: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.005.hdf5
# Epoch 11/15
# 250/250 [==============================] - 23s 92ms/step - loss: 2.5979e-04 - unstack_acc: 0.9730
#
# Epoch 00011: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.005.hdf5
# Epoch 12/15
# 250/250 [==============================] - 23s 90ms/step - loss: 2.5314e-04 - unstack_acc: 0.9740
#
# Epoch 00012: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.005.hdf5
# Epoch 13/15
# 250/250 [==============================] - 22s 90ms/step - loss: 2.4638e-04 - unstack_acc: 0.9748
#
# Epoch 00013: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.005.hdf5
# Epoch 14/15
# 250/250 [==============================] - 23s 91ms/step - loss: 2.4118e-04 - unstack_acc: 0.9751
#
# Epoch 00014: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.005.hdf5
# Epoch 15/15
# 250/250 [==============================] - 23s 92ms/step - loss: 2.3775e-04 - unstack_acc: 0.9756
#
# Epoch 00015: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.005.hdf5
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# true_input (InputLayer)         [(None, 192, 32, 1)] 0
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 192, 32, 64)  640         true_input[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 192, 32, 64)  36928       conv2d_66[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 96, 16, 64)   0           conv2d_67[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 96, 16, 128)  73856       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 96, 16, 128)  147584      conv2d_68[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 48, 8, 128)   0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 48, 8, 256)   295168      max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 48, 8, 256)   590080      conv2d_70[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 24, 4, 256)   0           conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 24, 4, 512)   1180160     max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 24, 4, 512)   2359808     conv2d_72[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 24, 4, 512)   0           conv2d_73[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 12, 2, 512)   0           dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 12, 2, 1024)  4719616     max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 12, 2, 1024)  9438208     conv2d_74[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 12, 2, 1024)  0           conv2d_75[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 24, 4, 1024)  0           dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 24, 4, 512)   2097664     up_sampling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 24, 4, 1024)  0           dropout_6[0][0]
#                                                                  conv2d_76[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 24, 4, 512)   4719104     concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 24, 4, 512)   2359808     conv2d_77[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 48, 8, 512)   0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 48, 8, 256)   524544      up_sampling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 48, 8, 512)   0           conv2d_71[0][0]
#                                                                  conv2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 48, 8, 256)   1179904     concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 48, 8, 256)   590080      conv2d_80[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 96, 16, 256)  0           conv2d_81[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 96, 16, 128)  131200      up_sampling2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 96, 16, 256)  0           conv2d_69[0][0]
#                                                                  conv2d_82[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 96, 16, 128)  295040      concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 96, 16, 128)  147584      conv2d_83[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 192, 32, 128) 0           conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 192, 32, 64)  32832       up_sampling2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 192, 32, 128) 0           conv2d_67[0][0]
#                                                                  conv2d_85[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 192, 32, 64)  73792       concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 192, 32, 64)  36928       conv2d_86[0][0]
# __________________________________________________________________________________________________
# true_output (Conv2D)            (None, 192, 32, 1)   65          conv2d_87[0][0]
# ==================================================================================================
# Total params: 31,030,593
# Trainable params: 31,030,593
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/15
# 250/250 [==============================] - 24s 92ms/step - loss: 0.0013 - unstack_acc: 0.8780
#
# Epoch 00001: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.01.hdf5
# Epoch 2/15
# 250/250 [==============================] - 24s 95ms/step - loss: 4.4858e-04 - unstack_acc: 0.9600
#
# Epoch 00002: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.01.hdf5
# Epoch 3/15
# 250/250 [==============================] - 23s 93ms/step - loss: 3.8749e-04 - unstack_acc: 0.9632 3s - lo
#
# Epoch 00003: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.01.hdf5
# Epoch 4/15
# 250/250 [==============================] - 23s 94ms/step - loss: 3.5636e-04 - unstack_acc: 0.9652
#
# Epoch 00004: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.01.hdf5
# Epoch 5/15
# 250/250 [==============================] - 23s 91ms/step - loss: 3.4138e-04 - unstack_acc: 0.9662
#
# Epoch 00005: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.01.hdf5
# Epoch 6/15
# 250/250 [==============================] - 23s 92ms/step - loss: 3.2402e-04 - unstack_acc: 0.9678
#
# Epoch 00006: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.01.hdf5
# Epoch 7/15
# 250/250 [==============================] - 23s 91ms/step - loss: 3.1298e-04 - unstack_acc: 0.9685
#
# Epoch 00007: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.01.hdf5
# Epoch 8/15
# 250/250 [==============================] - 23s 91ms/step - loss: 3.0852e-04 - unstack_acc: 0.9689
#
# Epoch 00008: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.01.hdf5
# Epoch 9/15
# ...
#
# Epoch 00001: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.75.hdf5
# Epoch 2/15
# 250/250 [==============================] - 23s 91ms/step - loss: 4.7508e-04 - unstack_acc: 0.9579
#
# Epoch 00002: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.75.hdf5
# Epoch 3/15
# 250/250 [==============================] - 23s 91ms/step - loss: 3.9696e-04 - unstack_acc: 0.9626
#
# Epoch 00003: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.75.hdf5
# Epoch 4/15
# 250/250 [==============================] - 23s 91ms/step - loss: 3.7572e-04 - unstack_acc: 0.9635
#
# Epoch 00004: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.75.hdf5
# Epoch 5/15
# 250/250 [==============================] - 23s 92ms/step - loss: 3.5958e-04 - unstack_acc: 0.9646
#
# Epoch 00005: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.75.hdf5
# Epoch 6/15
# 250/250 [==============================] - 23s 91ms/step - loss: 3.4380e-04 - unstack_acc: 0.9661
#
# Epoch 00006: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.75.hdf5
# Epoch 7/15
# 250/250 [==============================] - 23s 93ms/step - loss: 3.2944e-04 - unstack_acc: 0.9672
#
# Epoch 00007: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.75.hdf5
# Epoch 8/15
# 250/250 [==============================] - 22s 90ms/step - loss: 3.3185e-04 - unstack_acc: 0.9671
#
# Epoch 00008: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.75.hdf5
# Epoch 9/15
# 250/250 [==============================] - 24s 96ms/step - loss: 3.2480e-04 - unstack_acc: 0.9678
#
# Epoch 00009: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.75.hdf5
# Epoch 10/15
# 250/250 [==============================] - 23s 90ms/step - loss: 3.2036e-04 - unstack_acc: 0.9682
#
# Epoch 00010: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.75.hdf5
# Epoch 11/15
# 250/250 [==============================] - 23s 93ms/step - loss: 3.2281e-04 - unstack_acc: 0.9681
#
# Epoch 00011: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.75.hdf5
# Epoch 12/15
# 250/250 [==============================] - 23s 92ms/step - loss: 3.1000e-04 - unstack_acc: 0.9692
#
# Epoch 00012: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.75.hdf5
# Epoch 13/15
# 250/250 [==============================] - 23s 92ms/step - loss: 3.1055e-04 - unstack_acc: 0.9690
#
# Epoch 00013: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.75.hdf5
# Epoch 14/15
# 250/250 [==============================] - 23s 93ms/step - loss: 3.0524e-04 - unstack_acc: 0.9696
#
# Epoch 00014: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.75.hdf5
# Epoch 15/15
# 250/250 [==============================] - 26s 102ms/step - loss: 2.9899e-04 - unstack_acc: 0.9701
#
# Epoch 00015: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.75.hdf5
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# true_input (InputLayer)         [(None, 192, 32, 1)] 0
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 192, 32, 64)  640         true_input[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 192, 32, 64)  36928       conv2d_176[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 96, 16, 64)   0           conv2d_177[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 96, 16, 128)  73856       max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 96, 16, 128)  147584      conv2d_178[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 48, 8, 128)   0           conv2d_179[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 48, 8, 256)   295168      max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 48, 8, 256)   590080      conv2d_180[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_34 (MaxPooling2D) (None, 24, 4, 256)   0           conv2d_181[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 24, 4, 512)   1180160     max_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 24, 4, 512)   2359808     conv2d_182[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 24, 4, 512)   0           conv2d_183[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 12, 2, 512)   0           dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 12, 2, 1024)  4719616     max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 12, 2, 1024)  9438208     conv2d_184[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 12, 2, 1024)  0           conv2d_185[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_32 (UpSampling2D) (None, 24, 4, 1024)  0           dropout_17[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 24, 4, 512)   2097664     up_sampling2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 24, 4, 1024)  0           dropout_16[0][0]
#                                                                  conv2d_186[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 24, 4, 512)   4719104     concatenate_32[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 24, 4, 512)   2359808     conv2d_187[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_33 (UpSampling2D) (None, 48, 8, 512)   0           conv2d_188[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 48, 8, 256)   524544      up_sampling2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 48, 8, 512)   0           conv2d_181[0][0]
#                                                                  conv2d_189[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 48, 8, 256)   1179904     concatenate_33[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 48, 8, 256)   590080      conv2d_190[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_34 (UpSampling2D) (None, 96, 16, 256)  0           conv2d_191[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 96, 16, 128)  131200      up_sampling2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 96, 16, 256)  0           conv2d_179[0][0]
#                                                                  conv2d_192[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 96, 16, 128)  295040      concatenate_34[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 96, 16, 128)  147584      conv2d_193[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_35 (UpSampling2D) (None, 192, 32, 128) 0           conv2d_194[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 192, 32, 64)  32832       up_sampling2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 192, 32, 128) 0           conv2d_177[0][0]
#                                                                  conv2d_195[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 192, 32, 64)  73792       concatenate_35[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 192, 32, 64)  36928       conv2d_196[0][0]
# __________________________________________________________________________________________________
# true_output (Conv2D)            (None, 192, 32, 1)   65          conv2d_197[0][0]
# ==================================================================================================
# Total params: 31,030,593
# Trainable params: 31,030,593
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/15
# 250/250 [==============================] - 24s 91ms/step - loss: 0.0012 - unstack_acc: 0.8900
#
# Epoch 00001: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.9.hdf5
# Epoch 2/15
# 250/250 [==============================] - 23s 91ms/step - loss: 4.7502e-04 - unstack_acc: 0.9579
#
# Epoch 00002: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.9.hdf5
# Epoch 3/15
# 250/250 [==============================] - 23s 91ms/step - loss: 3.9126e-04 - unstack_acc: 0.9627
#
# Epoch 00003: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.9.hdf5
# Epoch 4/15
# 250/250 [==============================] - 23s 94ms/step - loss: 3.7857e-04 - unstack_acc: 0.9634
#
# Epoch 00004: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.9.hdf5
# Epoch 5/15
# 250/250 [==============================] - 23s 91ms/step - loss: 3.5393e-04 - unstack_acc: 0.9651
#
# Epoch 00005: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.9.hdf5
# Epoch 6/15
# 250/250 [==============================] - 23s 90ms/step - loss: 3.4124e-04 - unstack_acc: 0.9664
#
# Epoch 00006: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.9.hdf5
# Epoch 7/15
# 250/250 [==============================] - 22s 90ms/step - loss: 3.2737e-04 - unstack_acc: 0.9676
#
# Epoch 00007: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.9.hdf5
# Epoch 8/15
# 250/250 [==============================] - 22s 90ms/step - loss: 3.3173e-04 - unstack_acc: 0.9671
#
# Epoch 00008: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.9.hdf5
# Epoch 9/15
# 250/250 [==============================] - 22s 90ms/step - loss: 3.2892e-04 - unstack_acc: 0.9674
#
# Epoch 00009: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.9.hdf5
# Epoch 10/15
# 250/250 [==============================] - 22s 90ms/step - loss: 3.1972e-04 - unstack_acc: 0.9681
#
# Epoch 00010: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.9.hdf5
# Epoch 11/15
# 250/250 [==============================] - 22s 90ms/step - loss: 3.1719e-04 - unstack_acc: 0.9685
#
# Epoch 00011: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.9.hdf5
# Epoch 12/15
# 250/250 [==============================] - 23s 90ms/step - loss: 3.1392e-04 - unstack_acc: 0.9688
#
# Epoch 00012: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.9.hdf5
# Epoch 13/15
# 250/250 [==============================] - 22s 90ms/step - loss: 3.1262e-04 - unstack_acc: 0.9688
#
# Epoch 00013: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.9.hdf5
# Epoch 14/15
# 250/250 [==============================] - 23s 90ms/step - loss: 3.0800e-04 - unstack_acc: 0.9694
#
# Epoch 00014: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.9.hdf5
# Epoch 15/15
# 250/250 [==============================] - 22s 90ms/step - loss: 3.0376e-04 - unstack_acc: 0.9697
#
# Epoch 00015: saving model to /home/georgeos/Storage/Dropbox (Cambridge University)/Phase/delta_hist_mid_large/models/saved-model-frac-0.9.hdf5
